# %% [markdown]
# # Q2

# %% [markdown]
# *   In this question we will Build a bigram HMM tagger.
# *   First we split the part-of-speech-tagged corpus into a training set and test set.
# *   From the labeled training set, we train the transition and observation probabilities of the HMM tagger directly on the hand-tagged data.
# *   Then implement the Viterbi algorithm so we can decode a test sentence.
# *   Run the algorithm on the test set. Report its error rate and
# compare its performance to the most frequent tag baseline.
# *   Build a confusion matrix and investigate the most frequent errors.

# %%
import nltk
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# True

# %%
import math
import nltk
nltk.download('brown')
from nltk.corpus import brown
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %%
def collect_probabilities(_samples):
    """
    Collects various probabilities and frequencies required for Hidden Markov Model (HMM) training based on given samples.

    Args:
    _samples (list): A list of tuples containing (word, tag) pairs representing training data.

    Returns:
    tuple: A tuple containing four dictionaries:
           - tag_freq: A dictionary storing the frequency of each tag type.
           - word_per_tag_freq: A nested dictionary storing the frequency of each word under each tag.
           - bigram: A nested dictionary representing the bigram probabilities between tag types.
           - pi: A dictionary storing the initial probability distributions for tag types.

    Comments:
    - tag_freq: Stores the frequency of each tag type observed in the training data.
    - word_per_tag_freq: Stores the frequency of each word observed under each tag in the training data.
      - Each word under a specific tag is initialized with a count of 2 to provide initial smoothing.
    - bigram: Represents the transition probabilities between tag types based on bigram counts.
    - pi: Stores the initial probability distributions for tag types based on the second tag in each sample.
    """
    tag_freq = {}
    word_per_tag_freq = {}
    bigram = {}
    pi = {}
    samples_len = len(_samples)

    # Iterate through samples to collect tag frequencies, word frequencies under each tag, and initial probabilities
    for i in range(samples_len):
        sample = _samples[i]
        has_next = i + 1 < samples_len

        # Collect data for initial probabilities (pi)
        if has_next:
            if _samples[i + 1][1] not in pi:
                pi.update({_samples[i + 1][1]: 2})
            else:
               # Your code here
                pi[_samples[i + 1][1]] += 1

        # Count tag frequencies (tag_freq) and word frequencies under each tag (word_per_tag_freq)
        if sample[1] not in tag_freq:
            tag_freq.update({sample[1]: 2})
            word_per_tag_freq.update({sample[1]: {sample[0]: 2}})
        else:
           # Your code here
            tag_freq[sample[1]] += 1
            if sample[0] not in word_per_tag_freq[sample[1]]:
                word_per_tag_freq[sample[1]].update({sample[0]: 2})
            else:
                word_per_tag_freq[sample[1]][sample[0]] += 1

    # Initialize the bigram matrix with default counts
    for tag_0 in tag_freq:
      # Your code here
        bigram.update({tag_0: {}})
        for tag_1 in tag_freq:
            bigram[tag_0].update({tag_1: 1})

    # Count bigram occurrences
    for i in range(samples_len):
      # Your code here
        sample = _samples[i]
        has_next = i + 1 < samples_len

        if has_next:
            next_sample = _samples[i + 1]


    # Return collected probabilities and frequencies
    return tag_freq, word_per_tag_freq, bigram, pi

# %%
def create_confusion_matrix(predictions, hidden_state, confusion_matrices , is_correct):
    """
    Updates the confusion matrices based on the predictions and hidden states,
    calculates the number of correct predictions, and identifies tags with
    the most false positives and false negatives.

    Args:
    predictions (list): Predicted sequence of tags for the given input data.
    hidden_state (list): Actual sequence of tags for the given input data.
    confusion_matrices (dict): A dictionary containing confusion matrices for each tag.
    is_correct (int): Counter for the number of correct predictions.

    Returns:
    int: Updated count of correct predictions after processing the input data.

    Comments:
    - As the Viterbi algorithm processes each sentence in the test data,
      it compares the predicted tags against the actual tags for each word in the sentence.
        - For each word in the sentence, if the predicted tag matches the actual tag (a true positive),
          the corresponding count in the confusion matrix for that tag is incremented.
        - If the predicted tag does not match the actual tag:
            - If the predicted tag is incorrect (a false positive), the FP count for
              the predicted tag is incremented, and the TN counts for other tags are incremented.
            - If the actual tag is not predicted (a false negative), the FN count for the actual
              tag is incremented, and the TN counts for other tags are incremented.
    - After updating the confusion matrices, the function identifies tags with
      the highest counts of false positives and false negatives.
    """
    # fill in the confusion matrix
    for i in range(len(predictions)):
        if predictions[i] == hidden_state[i]:
            # prediction is correct
            is_correct += 1
            for j in confusion_matrices:
                # Your code here
                if j == predictions[i]:
                    confusion_matrices[j]['TP'] += 1
                else:
                    confusion_matrices[j]['TN'] += 1
        else:
            # prediction is incorrect
            for j in confusion_matrices:
                # Your code here
                if j == predictions[i]:
                    confusion_matrices[j]['FP'] += 1
                elif j == hidden_state[i]:
                    confusion_matrices[j]['FN'] += 1
                else:
                    confusion_matrices[j]['TN'] += 1

    # rank
    highest_FP_tag = []
    highest_FP = -1
    highest_FN_tag = []
    highest_FN = -1

    for tag in confusion_matrices:

        print(f'{tag}: {confusion_matrices[tag]}')

        if confusion_matrices[tag]['FP'] > highest_FP:
            highest_FP = confusion_matrices[tag]['FP']
            highest_FP_tag = tag

        if confusion_matrices[tag]['FN'] > highest_FN:
            highest_FN = confusion_matrices[tag]['FN']
            highest_FN_tag = tag

    print(f'\nTag with the most false positives is: {highest_FP_tag} with {highest_FP} counts.')
    print(f'Tag with the most false negative is:  {highest_FN_tag} with {highest_FN} counts.')

    return is_correct

# %%
def viterbi(_samples, _tag_freq, _word_per_tag_freq, _bigram, _init_dist):
    """
    Performs the Viterbi algorithm for part-of-speech tagging on a given test set of sentences.

    Args:
    _samples (list): A list of tuples containing (word, tag) pairs representing the test data.
    _tag_freq (dict): A dictionary storing the frequency of each tag type observed in the training data.
    _word_per_tag_freq (dict): A nested dictionary storing the frequency of each word observed under each tag in the training data.
    _bigram (dict): A nested dictionary representing the bigram probabilities between tag types.
    _init_dist (dict): A dictionary storing the initial probability distributions for tag types.

    Comments:
    - This function implements the Viterbi algorithm for part-of-speech tagging.
    - It processes each sentence in the test set, using '.' as an indicator that a sentence is over.
    - The function populates a confusion matrix to track the performance of the model.
    - The Viterbi algorithm is used to find the most likely sequence of tags for each sentence.
    - The algorithm iterates through each word in the sentence, calculating the most likely tag sequence based on probabilities and transition probabilities.
    - The model's predictions are compared against the actual tags to evaluate accuracy and populate the confusion matrix.
    - The function prints detailed information about predictions, including the sentence, hidden states, and predicted tags.
    - It also identifies tags with the most false positives and false negatives based on the confusion matrix.
    - Finally, the function prints the overall accuracy of the model on the test set.
    """
    test_size = len(_samples)
    current_index = 0
    is_correct = 0

    # populate the confusion matrix
    confusion_matrices = {}
    for tag in _tag_freq:
        confusion_matrices.update({tag: {'TP': 0, 'FP': 0, 'TN': 0, 'FN': 0}})

    while current_index < test_size:
        # find the boundry of a sentence
        sentence = []
        hidden_state = []
        last_token = ''
        while last_token != '.' and current_index < test_size:
            # sentence.append(''' Your code here ''')
            # hidden_state.append(''' Your code here ''')
            sentence.append(_samples[current_index][0])
            hidden_state.append(_samples[current_index][1])
            last_token = sentence[-1]
            current_index += 1

        # initialization step
        path_probability = {}
        backpointer = {}
        for tag in init_dist:
            path_probability.update({tag: []})
            backpointer.update({tag: [0]})

            # initial distribution of this tag
            pi_tag = init_dist[tag]

            # b_word is the probability of the word being generated by this tag
            if sentence[0] in _word_per_tag_freq[tag]:
                # Your code here
                b_word = _word_per_tag_freq[tag][sentence[0]] / _tag_freq[tag]
            else:
                b_word = 2.2250738585072014e-100
            # path_probability[tag].append(''' Your code here ''')
            path_probability[tag].append(math.log(pi_tag * b_word, 10))

        # recursion step
        T = len(sentence)
        for i in range(1, T):
            for tag in init_dist:

                if sentence[i] in _word_per_tag_freq[tag]:
                    # Your code here
                    b_word = _word_per_tag_freq[tag][sentence[i]] / _tag_freq[tag]
                else:
                    b_word = 2.2250738585072014e-100

                # search the maximum value of
                # viterbi[s', t-1] * a(s|s') *b_s(o_t)
                best_trans_prob = -2.2250738585072014e+308
                best_trans_tag = ''
                for prev_tag in init_dist:
                    if prev_tag in _bigram and tag in _bigram[prev_tag]:
                        # transitional_prob = # Your code here
                        transitional_prob = _bigram[prev_tag][tag] / _tag_freq[prev_tag]
                    else:
                        transitional_prob = 2.2250738585072014e-100

                    prob = path_probability[prev_tag][i - 1] + math.log(transitional_prob * b_word, 10)

                    if prob > best_trans_prob:
                        best_trans_prob = prob
                        best_trans_tag = prev_tag

                path_probability[tag].append(best_trans_prob)
                backpointer[tag].append(best_trans_tag)

        # termination step
        best_path_prob = -2.2250738585072014e+308
        best_path_pointer = None
        for tag in init_dist:
            # Your code here
            if path_probability[tag][T - 1] > best_path_prob:
                best_path_prob = path_probability[tag][T - 1]
                best_path_pointer = tag

        predictions = [best_path_pointer]

        # make the predictions path
        for i in reversed(range(1, T)):
            # Your code here
            prev_tag = predictions[-1]
            predictions.append(backpointer[prev_tag][i])
        predictions.reverse()

        print(f'sentence:       {sentence}')
        print(f'hidden s:       {hidden_state}')
        print(f'predictions:    {predictions}')

        is_correct = create_confusion_matrix(predictions, hidden_state, confusion_matrices, is_correct)

    print(f'\nmodel got {is_correct} samples correct out of {test_size}')
    print(f'accuracy: {is_correct / test_size}')

# %%
CORPUS = brown.tagged_words(categories='news', tagset='universal')
CORPUS_SIZE = len(brown.tagged_words(categories='news'))

CUT_OFF = math.floor(CORPUS_SIZE * 0.75)

# section off training and testing lists from corpus
training_list = CORPUS[:CUT_OFF]
testing_list = CORPUS[CUT_OFF:]

tag_frequency, word_per_tag_frequency, tag_bigram, init_dist = collect_probabilities(training_list)
viterbi(testing_list, tag_frequency, word_per_tag_frequency, tag_bigram, init_dist)
# Out:
# Streaming output truncated to the last 5000 lines.
# ADP: {'TP': 1713, 'FP': 14, 'TN': 16410, 'FN': 622}
# .: {'TP': 2272, 'FP': 0, 'TN': 16487, 'FN': 0}
# ADV: {'TP': 708, 'FP': 293, 'TN': 17633, 'FN': 125}
# CONJ: {'TP': 568, 'FP': 5, 'TN': 18182, 'FN': 4}
# PRT: {'TP': 480, 'FP': 341, 'TN': 17930, 'FN': 8}
# PRON: {'TP': 529, 'FP': 183, 'TN': 18045, 'FN': 2}
# NUM: {'TP': 301, 'FP': 18, 'TN': 18382, 'FN': 58}
# X: {'TP': 31, 'FP': 2181, 'TN': 16543, 'FN': 4}
#
# Tag with the most false positives is: X with 2181 counts.
# Tag with the most false negative is:  NOUN with 1657 counts.
# sentence:       ['Crime', ':', "'", 'skyjacked', "'", 'From', 'International', 'Airport', 'in', 'Los', 'Angeles', 'to', 'International', 'Airport', 'in', 'Houston', ',', 'as', 'the', 'great', 'four-jet', 'Boeing', '707', 'flies', ',', 'is', 'a', 'routine', 'five', 'hours', 'and', '25', 'minutes', ',', 'including', 'stopovers', 'at', 'Phoenix', ',', 'El', 'Paso', ',', 'and', 'San', 'Antonio', '.']
# hidden s:       ['NOUN', '.', '.', 'VERB', '.', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', 'NUM', 'VERB', '.', 'VERB', 'DET', 'ADJ', 'NUM', 'NOUN', 'CONJ', 'NUM', 'NOUN', '.', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.']
# predictions:    ['NOUN', '.', '.', 'X', '.', 'ADP', 'ADJ', 'X', 'ADP', 'NOUN', 'NOUN', 'PRT', 'ADJ', 'X', 'ADP', 'NOUN', '.', 'ADV', 'DET', 'ADJ', 'X', 'X', 'X', 'VERB', '.', 'VERB', 'DET', 'ADJ', 'NUM', 'NOUN', 'CONJ', 'NUM', 'NOUN', '.', 'ADP', 'X', 'ADP', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2214, 'FP': 6, 'TN': 16517, 'FN': 68}
# NOUN: {'TP': 3183, 'FP': 74, 'TN': 13887, 'FN': 1661}
# ADJ: {'TP': 1008, 'FP': 208, 'TN': 17052, 'FN': 537}
# VERB: {'TP': 2181, 'FP': 267, 'TN': 15850, 'FN': 507}
# ADP: {'TP': 1718, 'FP': 14, 'TN': 16449, 'FN': 624}
# .: {'TP': 2281, 'FP': 0, 'TN': 16524, 'FN': 0}
# ADV: {'TP': 708, 'FP': 294, 'TN': 17678, 'FN': 125}
# CONJ: {'TP': 570, 'FP': 5, 'TN': 18226, 'FN': 4}
# PRT: {'TP': 480, 'FP': 342, 'TN': 17975, 'FN': 8}
# PRON: {'TP': 529, 'FP': 183, 'TN': 18091, 'FN': 2}
# NUM: {'TP': 303, 'FP': 18, 'TN': 18425, 'FN': 59}
# X: {'TP': 31, 'FP': 2188, 'TN': 16582, 'FN': 4}
#
# Tag with the most false positives is: X with 2188 counts.
# Tag with the most false negative is:  NOUN with 1661 counts.
# sentence:       ['When', 'Continental', 'Airlines', 'night-coach', 'Flight', '54', 'took', 'off', 'at', '11:30', 'one', 'night', 'last', 'week', ',', 'there', 'was', 'no', 'reason', 'to', 'think', 'it', 'would', 'take', 'any', 'longer', '.']
# hidden s:       ['ADV', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'NUM', 'VERB', 'PRT', 'ADP', 'NUM', 'NUM', 'NOUN', 'ADJ', 'NOUN', '.', 'PRT', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'PRON', 'VERB', 'VERB', 'DET', 'ADJ', '.']
# predictions:    ['ADV', 'ADJ', 'X', 'X', 'X', 'NUM', 'VERB', 'PRT', 'ADP', 'NUM', 'NUM', 'NOUN', 'ADJ', 'NOUN', '.', 'PRT', 'VERB', 'ADV', 'NOUN', 'PRT', 'VERB', 'PRON', 'VERB', 'VERB', 'DET', 'ADV', '.']
# DET: {'TP': 2215, 'FP': 6, 'TN': 16542, 'FN': 69}
# NOUN: {'TP': 3186, 'FP': 74, 'TN': 13908, 'FN': 1664}
# ADJ: {'TP': 1010, 'FP': 208, 'TN': 17076, 'FN': 538}
# VERB: {'TP': 2186, 'FP': 267, 'TN': 15872, 'FN': 507}
# ADP: {'TP': 1719, 'FP': 14, 'TN': 16475, 'FN': 624}
# .: {'TP': 2283, 'FP': 0, 'TN': 16549, 'FN': 0}
# ADV: {'TP': 709, 'FP': 296, 'TN': 17702, 'FN': 125}
# CONJ: {'TP': 570, 'FP': 5, 'TN': 18253, 'FN': 4}
# PRT: {'TP': 483, 'FP': 342, 'TN': 17999, 'FN': 8}
# PRON: {'TP': 530, 'FP': 183, 'TN': 18117, 'FN': 2}
# NUM: {'TP': 306, 'FP': 18, 'TN': 18449, 'FN': 59}
# X: {'TP': 31, 'FP': 2191, 'TN': 16606, 'FN': 4}
#
# Tag with the most false positives is: X with 2191 counts.
# Tag with the most false negative is:  NOUN with 1664 counts.
# sentence:       ['The', 'plane', 'put', 'down', 'on', 'schedule', 'at', '1:35', 'a.m.', 'in', 'Phoenix', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'PRT', 'ADP', 'NOUN', 'ADP', 'NUM', 'ADV', 'ADP', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'VERB', 'PRT', 'PRT', 'NOUN', 'ADP', 'X', 'ADV', 'ADP', 'NOUN', '.']
# DET: {'TP': 2216, 'FP': 6, 'TN': 16553, 'FN': 69}
# NOUN: {'TP': 3189, 'FP': 74, 'TN': 13917, 'FN': 1664}
# ADJ: {'TP': 1010, 'FP': 208, 'TN': 17088, 'FN': 538}
# VERB: {'TP': 2187, 'FP': 267, 'TN': 15883, 'FN': 507}
# ADP: {'TP': 1721, 'FP': 14, 'TN': 16484, 'FN': 625}
# .: {'TP': 2284, 'FP': 0, 'TN': 16560, 'FN': 0}
# ADV: {'TP': 710, 'FP': 296, 'TN': 17713, 'FN': 125}
# CONJ: {'TP': 570, 'FP': 5, 'TN': 18265, 'FN': 4}
# PRT: {'TP': 484, 'FP': 343, 'TN': 18009, 'FN': 8}
# PRON: {'TP': 530, 'FP': 183, 'TN': 18129, 'FN': 2}
# NUM: {'TP': 306, 'FP': 18, 'TN': 18460, 'FN': 60}
# X: {'TP': 31, 'FP': 2192, 'TN': 16617, 'FN': 4}
#
# Tag with the most false positives is: X with 2192 counts.
# Tag with the most false negative is:  NOUN with 1664 counts.
# sentence:       ['Thirty-one', 'minutes', 'later', ',', 'when', 'it', 'took', 'off', 'for', 'El', 'Paso', ',', 'hardly', 'anyone', 'of', 'the', 'crew', 'of', 'six', 'or', 'the', '65', 'other', 'passengers', 'paid', 'any', 'attention', 'to', 'the', 'man', 'and', 'teen-age', 'boy', 'who', 'had', 'come', 'aboard', '.']
# hidden s:       ['NUM', 'NOUN', 'ADV', '.', 'ADV', 'PRON', 'VERB', 'PRT', 'ADP', 'NOUN', 'NOUN', '.', 'ADV', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NUM', 'CONJ', 'DET', 'NUM', 'ADJ', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'ADJ', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADV', '.']
# predictions:    ['ADJ', 'NOUN', 'ADV', '.', 'ADV', 'PRON', 'VERB', 'PRT', 'ADP', 'NOUN', 'NOUN', '.', 'ADV', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NUM', 'CONJ', 'DET', 'NUM', 'ADJ', 'NOUN', 'VERB', 'DET', 'NOUN', 'PRT', 'DET', 'NOUN', 'CONJ', 'X', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADV', '.']
# DET: {'TP': 2220, 'FP': 6, 'TN': 16587, 'FN': 69}
# NOUN: {'TP': 3198, 'FP': 74, 'TN': 13946, 'FN': 1664}
# ADJ: {'TP': 1011, 'FP': 209, 'TN': 17123, 'FN': 539}
# VERB: {'TP': 2191, 'FP': 267, 'TN': 15917, 'FN': 507}
# ADP: {'TP': 1724, 'FP': 14, 'TN': 16518, 'FN': 626}
# .: {'TP': 2287, 'FP': 0, 'TN': 16595, 'FN': 0}
# ADV: {'TP': 714, 'FP': 296, 'TN': 17747, 'FN': 125}
# CONJ: {'TP': 572, 'FP': 5, 'TN': 18301, 'FN': 4}
# PRT: {'TP': 485, 'FP': 344, 'TN': 18045, 'FN': 8}
# PRON: {'TP': 532, 'FP': 183, 'TN': 18165, 'FN': 2}
# NUM: {'TP': 308, 'FP': 18, 'TN': 18495, 'FN': 61}
# X: {'TP': 31, 'FP': 2193, 'TN': 16654, 'FN': 4}
#
# Tag with the most false positives is: X with 2193 counts.
# Tag with the most false negative is:  NOUN with 1664 counts.
# sentence:       ['At', '3:57', 'a.m.', ',', 'with', 'the', 'plane', 'about', 'twenty', 'minutes', 'out', 'of', 'El', 'Paso', ',', 'passenger', 'Robert', 'Berry', ',', 'a', 'San', 'Antonio', 'advertising', 'man', ',', 'glanced', 'up', 'and', 'saw', 'the', 'man', 'and', 'boy', ',', 'accompanied', 'by', 'a', 'stewardess', ',', 'walking', 'up', 'the', 'aisle', 'toward', 'the', 'cockpit', '.']
# hidden s:       ['ADP', 'NUM', 'ADV', '.', 'ADP', 'DET', 'NOUN', 'ADV', 'NUM', 'NOUN', 'ADP', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'NOUN', 'VERB', 'NOUN', '.', 'VERB', 'PRT', 'CONJ', 'VERB', 'DET', 'NOUN', 'CONJ', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['ADP', 'X', 'ADV', '.', 'ADP', 'DET', 'NOUN', 'ADV', 'NUM', 'NOUN', 'PRT', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'NOUN', 'VERB', 'NOUN', '.', 'X', 'PRT', 'CONJ', 'VERB', 'DET', 'NOUN', 'CONJ', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'X', '.', 'VERB', 'PRT', 'DET', 'X', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2226, 'FP': 6, 'TN': 16628, 'FN': 69}
# NOUN: {'TP': 3211, 'FP': 74, 'TN': 13978, 'FN': 1666}
# ADJ: {'TP': 1011, 'FP': 209, 'TN': 17170, 'FN': 539}
# VERB: {'TP': 2195, 'FP': 267, 'TN': 15959, 'FN': 508}
# ADP: {'TP': 1729, 'FP': 14, 'TN': 16558, 'FN': 628}
# .: {'TP': 2294, 'FP': 0, 'TN': 16635, 'FN': 0}
# ADV: {'TP': 716, 'FP': 296, 'TN': 17792, 'FN': 125}
# CONJ: {'TP': 574, 'FP': 5, 'TN': 18346, 'FN': 4}
# PRT: {'TP': 486, 'FP': 346, 'TN': 18089, 'FN': 8}
# PRON: {'TP': 532, 'FP': 183, 'TN': 18212, 'FN': 2}
# NUM: {'TP': 309, 'FP': 18, 'TN': 18540, 'FN': 62}
# X: {'TP': 31, 'FP': 2197, 'TN': 16697, 'FN': 4}
#
# Tag with the most false positives is: X with 2197 counts.
# Tag with the most false negative is:  NOUN with 1666 counts.
# sentence:       ['``', 'The', 'man', 'was', 'bent', 'over', 'with', 'his', 'hand', 'on', 'his', 'stomach', "''", ',', 'Berry', 'said', '.']
# hidden s:       ['.', 'DET', 'NOUN', 'VERB', 'VERB', 'PRT', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.', 'NOUN', 'VERB', '.']
# predictions:    ['.', 'DET', 'NOUN', 'VERB', 'X', 'PRT', 'ADP', 'DET', 'NOUN', 'PRT', 'DET', 'X', '.', '.', 'NOUN', 'VERB', '.']
# DET: {'TP': 2229, 'FP': 6, 'TN': 16642, 'FN': 69}
# NOUN: {'TP': 3214, 'FP': 74, 'TN': 13991, 'FN': 1667}
# ADJ: {'TP': 1011, 'FP': 209, 'TN': 17187, 'FN': 539}
# VERB: {'TP': 2197, 'FP': 267, 'TN': 15973, 'FN': 509}
# ADP: {'TP': 1730, 'FP': 14, 'TN': 16573, 'FN': 629}
# .: {'TP': 2298, 'FP': 0, 'TN': 16648, 'FN': 0}
# ADV: {'TP': 716, 'FP': 296, 'TN': 17809, 'FN': 125}
# CONJ: {'TP': 574, 'FP': 5, 'TN': 18363, 'FN': 4}
# PRT: {'TP': 487, 'FP': 347, 'TN': 18104, 'FN': 8}
# PRON: {'TP': 532, 'FP': 183, 'TN': 18229, 'FN': 2}
# NUM: {'TP': 309, 'FP': 18, 'TN': 18557, 'FN': 62}
# X: {'TP': 31, 'FP': 2199, 'TN': 16712, 'FN': 4}
#
# Tag with the most false positives is: X with 2199 counts.
# Tag with the most false negative is:  NOUN with 1667 counts.
# sentence:       ['``', 'I', 'figured', 'he', 'was', 'sick', "''", '.']
# hidden s:       ['.', 'PRON', 'VERB', 'PRON', 'VERB', 'ADJ', '.', '.']
# predictions:    ['.', 'PRON', 'VERB', 'PRON', 'VERB', 'X', '.', '.']
# DET: {'TP': 2229, 'FP': 6, 'TN': 16650, 'FN': 69}
# NOUN: {'TP': 3214, 'FP': 74, 'TN': 13999, 'FN': 1667}
# ADJ: {'TP': 1011, 'FP': 209, 'TN': 17194, 'FN': 540}
# VERB: {'TP': 2199, 'FP': 267, 'TN': 15979, 'FN': 509}
# ADP: {'TP': 1730, 'FP': 14, 'TN': 16581, 'FN': 629}
# .: {'TP': 2301, 'FP': 0, 'TN': 16653, 'FN': 0}
# ADV: {'TP': 716, 'FP': 296, 'TN': 17817, 'FN': 125}
# CONJ: {'TP': 574, 'FP': 5, 'TN': 18371, 'FN': 4}
# PRT: {'TP': 487, 'FP': 347, 'TN': 18112, 'FN': 8}
# PRON: {'TP': 534, 'FP': 183, 'TN': 18235, 'FN': 2}
# NUM: {'TP': 309, 'FP': 18, 'TN': 18565, 'FN': 62}
# X: {'TP': 31, 'FP': 2200, 'TN': 16719, 'FN': 4}
#
# Tag with the most false positives is: X with 2200 counts.
# Tag with the most false negative is:  NOUN with 1667 counts.
# sentence:       ['John', 'Salvador', ',', 'a', 'farmer', 'from', 'Palm', 'Desert', ',', 'Calif.', ',', 'was', 'sitting', 'up', 'front', 'and', 'could', 'see', 'through', 'the', 'door', 'as', 'the', 'trio', 'entered', 'the', 'cockpit', '.']
# hidden s:       ['NOUN', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', '.', 'VERB', 'VERB', 'ADP', 'NOUN', 'CONJ', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['NOUN', 'X', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'X', '.', 'NOUN', '.', 'VERB', 'VERB', 'PRT', 'NOUN', 'CONJ', 'VERB', 'VERB', 'PRT', 'DET', 'NOUN', 'ADV', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', '.']
# DET: {'TP': 2233, 'FP': 6, 'TN': 16674, 'FN': 69}
# NOUN: {'TP': 3222, 'FP': 74, 'TN': 14017, 'FN': 1669}
# ADJ: {'TP': 1011, 'FP': 209, 'TN': 17222, 'FN': 540}
# VERB: {'TP': 2204, 'FP': 267, 'TN': 16002, 'FN': 509}
# ADP: {'TP': 1731, 'FP': 14, 'TN': 16605, 'FN': 632}
# .: {'TP': 2305, 'FP': 0, 'TN': 16677, 'FN': 0}
# ADV: {'TP': 716, 'FP': 297, 'TN': 17844, 'FN': 125}
# CONJ: {'TP': 575, 'FP': 5, 'TN': 18398, 'FN': 4}
# PRT: {'TP': 487, 'FP': 349, 'TN': 18138, 'FN': 8}
# PRON: {'TP': 534, 'FP': 183, 'TN': 18263, 'FN': 2}
# NUM: {'TP': 309, 'FP': 18, 'TN': 18593, 'FN': 62}
# X: {'TP': 31, 'FP': 2202, 'TN': 16745, 'FN': 4}
#
# Tag with the most false positives is: X with 2202 counts.
# Tag with the most false negative is:  NOUN with 1669 counts.
# sentence:       ['``', 'The', 'kid', 'had', 'a', 'automatic', ',', 'like', 'they', 'issue', 'in', 'the', 'Army', "''", ',', 'he', 'said', '.']
# hidden s:       ['.', 'DET', 'NOUN', 'VERB', 'DET', 'ADJ', '.', 'ADP', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', '.', '.', 'PRON', 'VERB', '.']
# predictions:    ['.', 'DET', 'NOUN', 'VERB', 'DET', 'ADJ', '.', 'ADP', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', '.', '.', 'PRON', 'VERB', '.']
# DET: {'TP': 2236, 'FP': 6, 'TN': 16689, 'FN': 69}
# NOUN: {'TP': 3224, 'FP': 74, 'TN': 14033, 'FN': 1669}
# ADJ: {'TP': 1012, 'FP': 209, 'TN': 17239, 'FN': 540}
# VERB: {'TP': 2207, 'FP': 267, 'TN': 16017, 'FN': 509}
# ADP: {'TP': 1733, 'FP': 14, 'TN': 16621, 'FN': 632}
# .: {'TP': 2310, 'FP': 0, 'TN': 16690, 'FN': 0}
# ADV: {'TP': 716, 'FP': 297, 'TN': 17862, 'FN': 125}
# CONJ: {'TP': 575, 'FP': 5, 'TN': 18416, 'FN': 4}
# PRT: {'TP': 487, 'FP': 349, 'TN': 18156, 'FN': 8}
# PRON: {'TP': 536, 'FP': 183, 'TN': 18279, 'FN': 2}
# NUM: {'TP': 309, 'FP': 18, 'TN': 18611, 'FN': 62}
# X: {'TP': 31, 'FP': 2202, 'TN': 16763, 'FN': 4}
#
# Tag with the most false positives is: X with 2202 counts.
# Tag with the most false negative is:  NOUN with 1669 counts.
# sentence:       ['``', 'The', 'other', 'fellow', 'had', 'a', "''", '.']
# hidden s:       ['.', 'DET', 'ADJ', 'NOUN', 'VERB', 'DET', '.', '.']
# predictions:    ['.', 'DET', 'ADJ', 'NOUN', 'VERB', 'DET', '.', '.']
# DET: {'TP': 2238, 'FP': 6, 'TN': 16695, 'FN': 69}
# NOUN: {'TP': 3225, 'FP': 74, 'TN': 14040, 'FN': 1669}
# ADJ: {'TP': 1013, 'FP': 209, 'TN': 17246, 'FN': 540}
# VERB: {'TP': 2208, 'FP': 267, 'TN': 16024, 'FN': 509}
# ADP: {'TP': 1733, 'FP': 14, 'TN': 16629, 'FN': 632}
# .: {'TP': 2313, 'FP': 0, 'TN': 16695, 'FN': 0}
# ADV: {'TP': 716, 'FP': 297, 'TN': 17870, 'FN': 125}
# CONJ: {'TP': 575, 'FP': 5, 'TN': 18424, 'FN': 4}
# PRT: {'TP': 487, 'FP': 349, 'TN': 18164, 'FN': 8}
# PRON: {'TP': 536, 'FP': 183, 'TN': 18287, 'FN': 2}
# NUM: {'TP': 309, 'FP': 18, 'TN': 18619, 'FN': 62}
# X: {'TP': 31, 'FP': 2202, 'TN': 16771, 'FN': 4}
#
# Tag with the most false positives is: X with 2202 counts.
# Tag with the most false negative is:  NOUN with 1669 counts.
# sentence:       ['Salvador', 'saw', 'the', 'youth', 'hold', 'his', 'against', 'the', 'head', 'of', 'stewardess', 'Lois', 'Carnegey', ';', ';', 'the', 'man', 'put', 'his', 'at', 'the', 'head', 'of', 'Capt.', 'Byron', 'D.', 'Rickards', '.']
# hidden s:       ['NOUN', 'VERB', 'DET', 'NOUN', 'NOUN', 'DET', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', '.', '.', 'DET', 'NOUN', 'VERB', 'DET', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', 'NOUN', '.']
# predictions:    ['ADJ', 'VERB', 'DET', 'NOUN', 'VERB', 'DET', 'ADP', 'DET', 'ADJ', 'ADP', 'X', 'NOUN', 'X', '.', '.', 'DET', 'NOUN', 'VERB', 'DET', 'ADP', 'DET', 'ADJ', 'ADP', 'NOUN', 'NOUN', 'NOUN', 'X', '.']
# DET: {'TP': 2244, 'FP': 6, 'TN': 16717, 'FN': 69}
# NOUN: {'TP': 3231, 'FP': 74, 'TN': 14055, 'FN': 1676}
# ADJ: {'TP': 1013, 'FP': 212, 'TN': 17271, 'FN': 540}
# VERB: {'TP': 2210, 'FP': 268, 'TN': 16049, 'FN': 509}
# ADP: {'TP': 1737, 'FP': 14, 'TN': 16653, 'FN': 632}
# .: {'TP': 2316, 'FP': 0, 'TN': 16720, 'FN': 0}
# ADV: {'TP': 716, 'FP': 297, 'TN': 17898, 'FN': 125}
# CONJ: {'TP': 575, 'FP': 5, 'TN': 18452, 'FN': 4}
# PRT: {'TP': 487, 'FP': 349, 'TN': 18192, 'FN': 8}
# PRON: {'TP': 536, 'FP': 183, 'TN': 18315, 'FN': 2}
# NUM: {'TP': 309, 'FP': 18, 'TN': 18647, 'FN': 62}
# X: {'TP': 31, 'FP': 2205, 'TN': 16796, 'FN': 4}
#
# Tag with the most false positives is: X with 2205 counts.
# Tag with the most false negative is:  NOUN with 1676 counts.
# sentence:       ['To', 'Rickards', ',', 'a', '52-year-old', 'veteran', '30', 'years', 'in', 'the', 'air', ',', 'it', 'was', 'an', 'old', 'story', ':', 'His', 'plane', 'was', 'being', 'hijacked', 'in', 'mid-flight', 'again', 'much', 'as', 'it', 'had', 'happened', 'in', '1930', ',', 'when', 'Peruvian', 'rebels', 'made', 'him', 'land', 'a', 'Ford', 'tri-motor', 'at', 'Arequipa', '.']
# hidden s:       ['ADP', 'NOUN', '.', 'DET', 'ADJ', 'NOUN', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'PRON', 'VERB', 'DET', 'ADJ', 'NOUN', '.', 'DET', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADV', 'ADJ', 'ADP', 'PRON', 'VERB', 'VERB', 'ADP', 'NUM', '.', 'ADV', 'ADJ', 'NOUN', 'VERB', 'PRON', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['PRT', 'X', '.', 'DET', 'X', 'ADJ', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'PRON', 'VERB', 'DET', 'ADJ', 'NOUN', '.', 'DET', 'NOUN', 'VERB', 'VERB', 'X', 'ADP', 'X', 'ADV', 'ADV', 'ADV', 'PRON', 'VERB', 'VERB', 'ADP', 'NUM', '.', 'ADV', 'X', 'NOUN', 'VERB', 'PRON', 'VERB', 'DET', 'NOUN', 'X', 'ADP', 'X', '.']
# DET: {'TP': 2249, 'FP': 6, 'TN': 16758, 'FN': 69}
# NOUN: {'TP': 3237, 'FP': 74, 'TN': 14090, 'FN': 1681}
# ADJ: {'TP': 1014, 'FP': 213, 'TN': 17312, 'FN': 543}
# VERB: {'TP': 2217, 'FP': 268, 'TN': 16087, 'FN': 510}
# ADP: {'TP': 1741, 'FP': 14, 'TN': 16693, 'FN': 634}
# .: {'TP': 2321, 'FP': 0, 'TN': 16761, 'FN': 0}
# ADV: {'TP': 718, 'FP': 299, 'TN': 17940, 'FN': 125}
# CONJ: {'TP': 575, 'FP': 5, 'TN': 18498, 'FN': 4}
# PRT: {'TP': 487, 'FP': 350, 'TN': 18237, 'FN': 8}
# PRON: {'TP': 539, 'FP': 183, 'TN': 18358, 'FN': 2}
# NUM: {'TP': 311, 'FP': 18, 'TN': 18691, 'FN': 62}
# X: {'TP': 31, 'FP': 2212, 'TN': 16835, 'FN': 4}
#
# Tag with the most false positives is: X with 2212 counts.
# Tag with the most false negative is:  NOUN with 1681 counts.
# sentence:       ['But', 'last', "week's", 'pirates', ',', 'like', 'the', 'Cuban-American', 'who', 'recently', 'hijacked', 'an', 'Eastern', 'Airlines', 'Electra', '(', 'Newsweek', ',', 'Aug.', '7', ')', ',', 'wanted', 'to', 'go', 'to', 'Havana', '.']
# hidden s:       ['CONJ', 'ADJ', 'NOUN', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'PRON', 'ADV', 'VERB', 'DET', 'ADJ', 'NOUN', 'NOUN', '.', 'NOUN', '.', 'NOUN', 'NUM', '.', '.', 'VERB', 'PRT', 'VERB', 'ADP', 'NOUN', '.']
# predictions:    ['CONJ', 'ADJ', 'NOUN', 'X', '.', 'ADP', 'DET', 'X', 'PRON', 'ADV', 'X', 'DET', 'ADJ', 'X', 'X', '.', 'X', '.', 'NOUN', 'NUM', '.', '.', 'VERB', 'PRT', 'VERB', 'PRT', 'NOUN', '.']
# DET: {'TP': 2251, 'FP': 6, 'TN': 16784, 'FN': 69}
# NOUN: {'TP': 3240, 'FP': 74, 'TN': 14110, 'FN': 1686}
# ADJ: {'TP': 1016, 'FP': 213, 'TN': 17338, 'FN': 543}
# VERB: {'TP': 2219, 'FP': 268, 'TN': 16112, 'FN': 511}
# ADP: {'TP': 1742, 'FP': 14, 'TN': 16719, 'FN': 635}
# .: {'TP': 2327, 'FP': 0, 'TN': 16783, 'FN': 0}
# ADV: {'TP': 719, 'FP': 299, 'TN': 17967, 'FN': 125}
# CONJ: {'TP': 576, 'FP': 5, 'TN': 18525, 'FN': 4}
# PRT: {'TP': 488, 'FP': 351, 'TN': 18263, 'FN': 8}
# PRON: {'TP': 540, 'FP': 183, 'TN': 18385, 'FN': 2}
# NUM: {'TP': 312, 'FP': 18, 'TN': 18718, 'FN': 62}
# X: {'TP': 31, 'FP': 2218, 'TN': 16857, 'FN': 4}
#
# Tag with the most false positives is: X with 2218 counts.
# Tag with the most false negative is:  NOUN with 1686 counts.
# sentence:       ['Stalling', ':', '``', 'Tell', 'your', 'company', 'there', 'are', 'four', 'of', 'us', 'here', 'with', 'guns', "''", ',', 'the', 'elder', 'man', 'told', 'Rickards', '.']
# hidden s:       ['VERB', '.', '.', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'NUM', 'ADP', 'PRON', 'ADV', 'ADP', 'NOUN', '.', '.', 'DET', 'ADJ', 'NOUN', 'VERB', 'NOUN', '.']
# predictions:    ['ADJ', '.', '.', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'NUM', 'ADP', 'PRON', 'ADV', 'ADP', 'X', '.', '.', 'DET', 'X', 'NOUN', 'VERB', 'X', '.']
# DET: {'TP': 2253, 'FP': 6, 'TN': 16804, 'FN': 69}
# NOUN: {'TP': 3242, 'FP': 74, 'TN': 14128, 'FN': 1688}
# ADJ: {'TP': 1016, 'FP': 214, 'TN': 17358, 'FN': 544}
# VERB: {'TP': 2222, 'FP': 268, 'TN': 16130, 'FN': 512}
# ADP: {'TP': 1744, 'FP': 14, 'TN': 16739, 'FN': 635}
# .: {'TP': 2332, 'FP': 0, 'TN': 16800, 'FN': 0}
# ADV: {'TP': 720, 'FP': 299, 'TN': 17988, 'FN': 125}
# CONJ: {'TP': 576, 'FP': 5, 'TN': 18547, 'FN': 4}
# PRT: {'TP': 489, 'FP': 351, 'TN': 18284, 'FN': 8}
# PRON: {'TP': 541, 'FP': 183, 'TN': 18406, 'FN': 2}
# NUM: {'TP': 313, 'FP': 18, 'TN': 18739, 'FN': 62}
# X: {'TP': 31, 'FP': 2221, 'TN': 16876, 'FN': 4}
#
# Tag with the most false positives is: X with 2221 counts.
# Tag with the most false negative is:  NOUN with 1688 counts.
# sentence:       ['The', 'pilot', 'radioed', 'El', 'Paso', 'International', 'Airport', 'with', 'just', 'that', 'message', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'ADP', 'ADV', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'X', 'NOUN', 'NOUN', 'ADJ', 'X', 'ADP', 'ADV', 'PRON', 'NOUN', '.']
# DET: {'TP': 2254, 'FP': 6, 'TN': 16814, 'FN': 70}
# NOUN: {'TP': 3246, 'FP': 74, 'TN': 14135, 'FN': 1689}
# ADJ: {'TP': 1017, 'FP': 214, 'TN': 17369, 'FN': 544}
# VERB: {'TP': 2222, 'FP': 268, 'TN': 16141, 'FN': 513}
# ADP: {'TP': 1745, 'FP': 14, 'TN': 16750, 'FN': 635}
# .: {'TP': 2333, 'FP': 0, 'TN': 16811, 'FN': 0}
# ADV: {'TP': 721, 'FP': 299, 'TN': 17999, 'FN': 125}
# CONJ: {'TP': 576, 'FP': 5, 'TN': 18559, 'FN': 4}
# PRT: {'TP': 489, 'FP': 351, 'TN': 18296, 'FN': 8}
# PRON: {'TP': 541, 'FP': 184, 'TN': 18417, 'FN': 2}
# NUM: {'TP': 313, 'FP': 18, 'TN': 18751, 'FN': 62}
# X: {'TP': 31, 'FP': 2223, 'TN': 16886, 'FN': 4}
#
# Tag with the most false positives is: X with 2223 counts.
# Tag with the most false negative is:  NOUN with 1689 counts.
# sentence:       ['But', ',', 'he', 'told', 'the', '``', 'skyjackers', "''", ',', 'the', '707', "didn't", 'carry', 'enough', 'fuel', 'to', 'reach', 'Havana', ';', ';', 'they', 'would', 'have', 'to', 'refuel', 'at', 'El', 'Paso', '.']
# hidden s:       ['CONJ', '.', 'PRON', 'VERB', 'DET', '.', 'NOUN', '.', '.', 'DET', 'NUM', 'VERB', 'VERB', 'ADJ', 'NOUN', 'PRT', 'VERB', 'NOUN', '.', '.', 'PRON', 'VERB', 'VERB', 'PRT', 'VERB', 'ADP', 'NOUN', 'NOUN', '.']
# predictions:    ['CONJ', '.', 'PRON', 'VERB', 'DET', '.', 'X', '.', '.', 'DET', 'X', 'VERB', 'VERB', 'ADV', 'NOUN', 'PRT', 'VERB', 'NOUN', '.', '.', 'PRON', 'VERB', 'VERB', 'PRT', 'X', 'ADP', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2256, 'FP': 6, 'TN': 16841, 'FN': 70}
# NOUN: {'TP': 3250, 'FP': 74, 'TN': 14159, 'FN': 1690}
# ADJ: {'TP': 1017, 'FP': 214, 'TN': 17397, 'FN': 545}
# VERB: {'TP': 2228, 'FP': 268, 'TN': 16163, 'FN': 514}
# ADP: {'TP': 1746, 'FP': 14, 'TN': 16778, 'FN': 635}
# .: {'TP': 2340, 'FP': 0, 'TN': 16833, 'FN': 0}
# ADV: {'TP': 721, 'FP': 300, 'TN': 18027, 'FN': 125}
# CONJ: {'TP': 577, 'FP': 5, 'TN': 18587, 'FN': 4}
# PRT: {'TP': 491, 'FP': 351, 'TN': 18323, 'FN': 8}
# PRON: {'TP': 543, 'FP': 184, 'TN': 18444, 'FN': 2}
# NUM: {'TP': 313, 'FP': 18, 'TN': 18779, 'FN': 63}
# X: {'TP': 31, 'FP': 2226, 'TN': 16912, 'FN': 4}
#
# Tag with the most false positives is: X with 2226 counts.
# Tag with the most false negative is:  NOUN with 1690 counts.
# sentence:       ['Most', 'passengers', "didn't", 'know', 'what', 'had', 'happened', 'until', 'they', 'got', 'on', 'the', 'ground', '.']
# hidden s:       ['ADJ', 'NOUN', 'VERB', 'VERB', 'DET', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['ADJ', 'NOUN', 'VERB', 'VERB', 'DET', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'PRT', 'DET', 'NOUN', '.']
# DET: {'TP': 2258, 'FP': 6, 'TN': 16853, 'FN': 70}
# NOUN: {'TP': 3252, 'FP': 74, 'TN': 14171, 'FN': 1690}
# ADJ: {'TP': 1018, 'FP': 214, 'TN': 17410, 'FN': 545}
# VERB: {'TP': 2233, 'FP': 268, 'TN': 16172, 'FN': 514}
# ADP: {'TP': 1747, 'FP': 14, 'TN': 16790, 'FN': 636}
# .: {'TP': 2341, 'FP': 0, 'TN': 16846, 'FN': 0}
# ADV: {'TP': 721, 'FP': 300, 'TN': 18041, 'FN': 125}
# CONJ: {'TP': 577, 'FP': 5, 'TN': 18601, 'FN': 4}
# PRT: {'TP': 491, 'FP': 352, 'TN': 18336, 'FN': 8}
# PRON: {'TP': 544, 'FP': 184, 'TN': 18457, 'FN': 2}
# NUM: {'TP': 313, 'FP': 18, 'TN': 18793, 'FN': 63}
# X: {'TP': 31, 'FP': 2226, 'TN': 16926, 'FN': 4}
#
# Tag with the most false positives is: X with 2226 counts.
# Tag with the most false negative is:  NOUN with 1690 counts.
# sentence:       ['Jerry', 'McCauley', 'of', 'Sacramento', ',', 'Calif.', ',', 'one', 'of', 'some', 'twenty', 'Air', 'Force', 'recruits', 'on', 'board', ',', 'awoke', 'from', 'a', 'nap', 'in', 'confusion', '.']
# hidden s:       ['NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'NUM', 'ADP', 'DET', 'NUM', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['NOUN', 'X', 'ADP', 'X', '.', 'NOUN', '.', 'NUM', 'ADP', 'DET', 'NUM', 'NOUN', 'NOUN', 'X', 'PRT', 'NOUN', '.', 'X', 'ADP', 'DET', 'X', 'ADP', 'NOUN', '.']
# DET: {'TP': 2260, 'FP': 6, 'TN': 16875, 'FN': 70}
# NOUN: {'TP': 3258, 'FP': 74, 'TN': 14185, 'FN': 1694}
# ADJ: {'TP': 1018, 'FP': 214, 'TN': 17434, 'FN': 545}
# VERB: {'TP': 2233, 'FP': 268, 'TN': 16195, 'FN': 515}
# ADP: {'TP': 1751, 'FP': 14, 'TN': 16809, 'FN': 637}
# .: {'TP': 2345, 'FP': 0, 'TN': 16866, 'FN': 0}
# ADV: {'TP': 721, 'FP': 300, 'TN': 18065, 'FN': 125}
# CONJ: {'TP': 577, 'FP': 5, 'TN': 18625, 'FN': 4}
# PRT: {'TP': 491, 'FP': 353, 'TN': 18359, 'FN': 8}
# PRON: {'TP': 544, 'FP': 184, 'TN': 18481, 'FN': 2}
# NUM: {'TP': 315, 'FP': 18, 'TN': 18815, 'FN': 63}
# X: {'TP': 31, 'FP': 2231, 'TN': 16945, 'FN': 4}
#
# Tag with the most false positives is: X with 2231 counts.
# Tag with the most false negative is:  NOUN with 1694 counts.
# sentence:       ['``', 'The', 'old', 'man', 'came', 'from', 'the', 'front', 'of', 'the', 'plane', 'and', 'said', 'he', 'wanted', 'four', 'volunteers', 'to', 'go', 'to', 'Cuba', "''", ',', 'McCauley', 'said', ',', '``', 'and', 'like', 'a', 'nut', 'I', 'raised', 'my', 'hand', '.']
# hidden s:       ['.', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'VERB', 'PRON', 'VERB', 'NUM', 'NOUN', 'PRT', 'VERB', 'ADP', 'NOUN', '.', '.', 'NOUN', 'VERB', '.', '.', 'CONJ', 'ADP', 'DET', 'NOUN', 'PRON', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['.', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'VERB', 'PRON', 'VERB', 'NUM', 'NOUN', 'PRT', 'VERB', 'PRT', 'NOUN', '.', '.', 'X', 'VERB', '.', '.', 'CONJ', 'ADP', 'DET', 'X', 'PRON', 'VERB', 'DET', 'NOUN', '.']
# DET: {'TP': 2265, 'FP': 6, 'TN': 16906, 'FN': 70}
# NOUN: {'TP': 3264, 'FP': 74, 'TN': 14213, 'FN': 1696}
# ADJ: {'TP': 1019, 'FP': 214, 'TN': 17469, 'FN': 545}
# VERB: {'TP': 2239, 'FP': 268, 'TN': 16225, 'FN': 515}
# ADP: {'TP': 1754, 'FP': 14, 'TN': 16841, 'FN': 638}
# .: {'TP': 2351, 'FP': 0, 'TN': 16896, 'FN': 0}
# ADV: {'TP': 721, 'FP': 300, 'TN': 18101, 'FN': 125}
# CONJ: {'TP': 579, 'FP': 5, 'TN': 18659, 'FN': 4}
# PRT: {'TP': 492, 'FP': 354, 'TN': 18393, 'FN': 8}
# PRON: {'TP': 546, 'FP': 184, 'TN': 18515, 'FN': 2}
# NUM: {'TP': 316, 'FP': 18, 'TN': 18850, 'FN': 63}
# X: {'TP': 31, 'FP': 2233, 'TN': 16979, 'FN': 4}
#
# Tag with the most false positives is: X with 2233 counts.
# Tag with the most false negative is:  NOUN with 1696 counts.
# sentence:       ['I', 'thought', 'he', 'was', 'the', 'Air', 'Force', 'recruiter', "''", '.']
# hidden s:       ['PRON', 'VERB', 'PRON', 'VERB', 'DET', 'NOUN', 'NOUN', 'NOUN', '.', '.']
# predictions:    ['PRON', 'VERB', 'PRON', 'VERB', 'DET', 'NOUN', 'NOUN', 'X', '.', '.']
# DET: {'TP': 2266, 'FP': 6, 'TN': 16915, 'FN': 70}
# NOUN: {'TP': 3266, 'FP': 74, 'TN': 14220, 'FN': 1697}
# ADJ: {'TP': 1019, 'FP': 214, 'TN': 17479, 'FN': 545}
# VERB: {'TP': 2241, 'FP': 268, 'TN': 16233, 'FN': 515}
# ADP: {'TP': 1754, 'FP': 14, 'TN': 16851, 'FN': 638}
# .: {'TP': 2353, 'FP': 0, 'TN': 16904, 'FN': 0}
# ADV: {'TP': 721, 'FP': 300, 'TN': 18111, 'FN': 125}
# CONJ: {'TP': 579, 'FP': 5, 'TN': 18669, 'FN': 4}
# PRT: {'TP': 492, 'FP': 354, 'TN': 18403, 'FN': 8}
# PRON: {'TP': 548, 'FP': 184, 'TN': 18523, 'FN': 2}
# NUM: {'TP': 316, 'FP': 18, 'TN': 18860, 'FN': 63}
# X: {'TP': 31, 'FP': 2234, 'TN': 16988, 'FN': 4}
#
# Tag with the most false positives is: X with 2234 counts.
# Tag with the most false negative is:  NOUN with 1697 counts.
# sentence:       ['What', 'the', 'man', 'wanted', 'was', 'four', 'persons', 'to', 'volunteer', 'as', 'hostages', ',', 'along', 'with', 'the', 'crew', '.']
# hidden s:       ['DET', 'DET', 'NOUN', 'VERB', 'VERB', 'NUM', 'NOUN', 'PRT', 'VERB', 'ADP', 'NOUN', '.', 'ADP', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'DET', 'NOUN', 'VERB', 'VERB', 'NUM', 'NOUN', 'PRT', 'X', 'ADV', 'X', '.', 'ADV', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2269, 'FP': 6, 'TN': 16929, 'FN': 70}
# NOUN: {'TP': 3269, 'FP': 74, 'TN': 14233, 'FN': 1698}
# ADJ: {'TP': 1019, 'FP': 214, 'TN': 17496, 'FN': 545}
# VERB: {'TP': 2243, 'FP': 268, 'TN': 16247, 'FN': 516}
# ADP: {'TP': 1755, 'FP': 14, 'TN': 16865, 'FN': 640}
# .: {'TP': 2355, 'FP': 0, 'TN': 16919, 'FN': 0}
# ADV: {'TP': 721, 'FP': 302, 'TN': 18126, 'FN': 125}
# CONJ: {'TP': 579, 'FP': 5, 'TN': 18686, 'FN': 4}
# PRT: {'TP': 493, 'FP': 354, 'TN': 18419, 'FN': 8}
# PRON: {'TP': 548, 'FP': 184, 'TN': 18540, 'FN': 2}
# NUM: {'TP': 317, 'FP': 18, 'TN': 18876, 'FN': 63}
# X: {'TP': 31, 'FP': 2236, 'TN': 17003, 'FN': 4}
#
# Tag with the most false positives is: X with 2236 counts.
# Tag with the most false negative is:  NOUN with 1698 counts.
# sentence:       ['They', 'chose', 'four', ':', 'Jack', 'Casey', ',', 'who', 'works', 'for', 'Continental', 'Airlines', 'in', 'Houston', ';', ';', 'Fred', 'Mullen', 'from', 'Mercer', 'Island', ',', 'Wash.', ';', ';', 'Pfc.', 'Truman', 'Cleveland', 'of', 'St.', 'Augustine', '.']
# hidden s:       ['PRON', 'VERB', 'NUM', '.', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', '.', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', '.', '.', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.']
# predictions:    ['PRON', 'VERB', 'NUM', '.', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'ADJ', 'X', 'ADP', 'NOUN', '.', '.', 'NOUN', 'X', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', '.', '.', 'X', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'X', '.']
# DET: {'TP': 2269, 'FP': 6, 'TN': 16961, 'FN': 70}
# NOUN: {'TP': 3279, 'FP': 74, 'TN': 14251, 'FN': 1702}
# ADJ: {'TP': 1020, 'FP': 214, 'TN': 17527, 'FN': 545}
# VERB: {'TP': 2245, 'FP': 268, 'TN': 16277, 'FN': 516}
# ADP: {'TP': 1759, 'FP': 14, 'TN': 16893, 'FN': 640}
# .: {'TP': 2363, 'FP': 0, 'TN': 16943, 'FN': 0}
# ADV: {'TP': 721, 'FP': 302, 'TN': 18158, 'FN': 125}
# CONJ: {'TP': 579, 'FP': 5, 'TN': 18718, 'FN': 4}
# PRT: {'TP': 493, 'FP': 354, 'TN': 18451, 'FN': 8}
# PRON: {'TP': 550, 'FP': 184, 'TN': 18570, 'FN': 2}
# NUM: {'TP': 318, 'FP': 18, 'TN': 18907, 'FN': 63}
# X: {'TP': 31, 'FP': 2240, 'TN': 17031, 'FN': 4}
#
# Tag with the most false positives is: X with 2240 counts.
# Tag with the most false negative is:  NOUN with 1702 counts.
# sentence:       ['Fla.', ',', 'and', 'Leonard', 'Gilman', ',', 'a', 'former', 'college', 'boxer', 'and', 'veteran', 'of', 'the', 'U.S.', 'Immigration', 'Service', 'Border', 'Patrol', '.']
# hidden s:       ['NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.', 'DET', 'ADJ', 'NOUN', 'NOUN', 'CONJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', '.']
# predictions:    ['NOUN', '.', 'CONJ', 'NOUN', 'X', '.', 'DET', 'ADJ', 'NOUN', 'X', 'CONJ', 'ADJ', 'ADP', 'DET', 'NOUN', 'X', 'NOUN', 'X', 'NOUN', '.']
# DET: {'TP': 2271, 'FP': 6, 'TN': 16979, 'FN': 70}
# NOUN: {'TP': 3285, 'FP': 74, 'TN': 14260, 'FN': 1707}
# ADJ: {'TP': 1021, 'FP': 215, 'TN': 17545, 'FN': 545}
# VERB: {'TP': 2245, 'FP': 268, 'TN': 16297, 'FN': 516}
# ADP: {'TP': 1760, 'FP': 14, 'TN': 16912, 'FN': 640}
# .: {'TP': 2366, 'FP': 0, 'TN': 16960, 'FN': 0}
# ADV: {'TP': 721, 'FP': 302, 'TN': 18178, 'FN': 125}
# CONJ: {'TP': 581, 'FP': 5, 'TN': 18736, 'FN': 4}
# PRT: {'TP': 493, 'FP': 354, 'TN': 18471, 'FN': 8}
# PRON: {'TP': 550, 'FP': 184, 'TN': 18590, 'FN': 2}
# NUM: {'TP': 318, 'FP': 18, 'TN': 18927, 'FN': 63}
# X: {'TP': 31, 'FP': 2244, 'TN': 17047, 'FN': 4}
#
# Tag with the most false positives is: X with 2244 counts.
# Tag with the most false negative is:  NOUN with 1707 counts.
# sentence:       ['Everybody', 'else', 'was', 'allowed', 'to', 'file', 'off', 'the', 'plane', 'after', 'it', 'touched', 'down', 'at', 'El', 'Paso', 'at', '4:18', 'a.m.', '.']
# hidden s:       ['NOUN', 'ADV', 'VERB', 'VERB', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', 'PRT', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NUM', 'ADV', '.']
# predictions:    ['NOUN', 'ADV', 'VERB', 'VERB', 'PRT', 'NOUN', 'PRT', 'DET', 'NOUN', 'ADP', 'PRON', 'X', 'PRT', 'ADP', 'NOUN', 'NOUN', 'ADP', 'X', 'ADV', '.']
# DET: {'TP': 2272, 'FP': 6, 'TN': 16998, 'FN': 70}
# NOUN: {'TP': 3289, 'FP': 75, 'TN': 14275, 'FN': 1707}
# ADJ: {'TP': 1021, 'FP': 215, 'TN': 17565, 'FN': 545}
# VERB: {'TP': 2247, 'FP': 268, 'TN': 16313, 'FN': 518}
# ADP: {'TP': 1763, 'FP': 14, 'TN': 16928, 'FN': 641}
# .: {'TP': 2367, 'FP': 0, 'TN': 16979, 'FN': 0}
# ADV: {'TP': 723, 'FP': 302, 'TN': 18196, 'FN': 125}
# CONJ: {'TP': 581, 'FP': 5, 'TN': 18756, 'FN': 4}
# PRT: {'TP': 495, 'FP': 355, 'TN': 18488, 'FN': 8}
# PRON: {'TP': 551, 'FP': 184, 'TN': 18609, 'FN': 2}
# NUM: {'TP': 318, 'FP': 18, 'TN': 18946, 'FN': 64}
# X: {'TP': 31, 'FP': 2246, 'TN': 17065, 'FN': 4}
#
# Tag with the most false positives is: X with 2246 counts.
# Tag with the most false negative is:  NOUN with 1707 counts.
# sentence:       ['They', 'found', 'a', 'large', 'welcoming', 'group', '--', 'El', 'Paso', 'policemen', ',', 'Border', 'Patrol', ',', "sheriff's", 'deputies', ',', 'and', 'FBI', 'men', ',', 'who', 'surged', 'around', 'the', 'plane', 'with', 'rifles', 'and', 'submachine', 'guns', '.']
# hidden s:       ['PRON', 'VERB', 'DET', 'ADJ', 'VERB', 'NOUN', '.', 'NOUN', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'ADJ', 'NOUN', '.']
# predictions:    ['PRON', 'VERB', 'DET', 'ADJ', 'VERB', 'NOUN', '.', 'NOUN', 'NOUN', 'NOUN', '.', 'X', 'NOUN', '.', 'X', 'NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.', 'PRON', 'X', 'ADV', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'X', 'X', '.']
# DET: {'TP': 2274, 'FP': 6, 'TN': 17028, 'FN': 70}
# NOUN: {'TP': 3299, 'FP': 75, 'TN': 14294, 'FN': 1710}
# ADJ: {'TP': 1022, 'FP': 215, 'TN': 17595, 'FN': 546}
# VERB: {'TP': 2249, 'FP': 268, 'TN': 16342, 'FN': 519}
# ADP: {'TP': 1764, 'FP': 14, 'TN': 16958, 'FN': 642}
# .: {'TP': 2373, 'FP': 0, 'TN': 17005, 'FN': 0}
# ADV: {'TP': 723, 'FP': 303, 'TN': 18227, 'FN': 125}
# CONJ: {'TP': 583, 'FP': 5, 'TN': 18786, 'FN': 4}
# PRT: {'TP': 495, 'FP': 355, 'TN': 18520, 'FN': 8}
# PRON: {'TP': 553, 'FP': 184, 'TN': 18639, 'FN': 2}
# NUM: {'TP': 318, 'FP': 18, 'TN': 18978, 'FN': 64}
# X: {'TP': 31, 'FP': 2251, 'TN': 17092, 'FN': 4}
#
# Tag with the most false positives is: X with 2251 counts.
# Tag with the most false negative is:  NOUN with 1710 counts.
# sentence:       ['Other', 'FBI', 'men', ',', 'talking', 'with', 'the', 'pilot', 'from', 'the', 'tower', ',', 'conspired', 'with', 'him', 'to', 'delay', 'the', 'proposed', 'flight', 'to', 'Havana', '.']
# hidden s:       ['ADJ', 'NOUN', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'PRON', 'PRT', 'VERB', 'DET', 'VERB', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['ADJ', 'NOUN', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'X', '.', 'X', 'ADP', 'PRON', 'PRT', 'NOUN', 'DET', 'VERB', 'NOUN', 'PRT', 'NOUN', '.']
# DET: {'TP': 2277, 'FP': 6, 'TN': 17048, 'FN': 70}
# NOUN: {'TP': 3304, 'FP': 76, 'TN': 14310, 'FN': 1711}
# ADJ: {'TP': 1023, 'FP': 215, 'TN': 17617, 'FN': 546}
# VERB: {'TP': 2251, 'FP': 268, 'TN': 16361, 'FN': 521}
# ADP: {'TP': 1767, 'FP': 14, 'TN': 16977, 'FN': 643}
# .: {'TP': 2376, 'FP': 0, 'TN': 17025, 'FN': 0}
# ADV: {'TP': 723, 'FP': 303, 'TN': 18250, 'FN': 125}
# CONJ: {'TP': 583, 'FP': 5, 'TN': 18809, 'FN': 4}
# PRT: {'TP': 496, 'FP': 356, 'TN': 18541, 'FN': 8}
# PRON: {'TP': 554, 'FP': 184, 'TN': 18661, 'FN': 2}
# NUM: {'TP': 318, 'FP': 18, 'TN': 19001, 'FN': 64}
# X: {'TP': 31, 'FP': 2253, 'TN': 17113, 'FN': 4}
#
# Tag with the most false positives is: X with 2253 counts.
# Tag with the most false negative is:  NOUN with 1711 counts.
# sentence:       ['The', 'ground', 'crew', ',', 'which', 'ordinarily', 'fuels', 'a', '707', 'in', 'twenty', 'minutes', ',', 'took', 'fully', 'three', 'hours', '.']
# hidden s:       ['DET', 'NOUN', 'NOUN', '.', 'DET', 'ADV', 'VERB', 'DET', 'NUM', 'ADP', 'NUM', 'NOUN', '.', 'VERB', 'ADV', 'NUM', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'NOUN', '.', 'DET', 'X', 'X', 'DET', 'X', 'ADP', 'NUM', 'NOUN', '.', 'VERB', 'ADV', 'NUM', 'NOUN', '.']
# DET: {'TP': 2280, 'FP': 6, 'TN': 17063, 'FN': 70}
# NOUN: {'TP': 3308, 'FP': 76, 'TN': 14324, 'FN': 1711}
# ADJ: {'TP': 1023, 'FP': 215, 'TN': 17635, 'FN': 546}
# VERB: {'TP': 2252, 'FP': 268, 'TN': 16377, 'FN': 522}
# ADP: {'TP': 1768, 'FP': 14, 'TN': 16994, 'FN': 643}
# .: {'TP': 2379, 'FP': 0, 'TN': 17040, 'FN': 0}
# ADV: {'TP': 724, 'FP': 303, 'TN': 18266, 'FN': 126}
# CONJ: {'TP': 583, 'FP': 5, 'TN': 18827, 'FN': 4}
# PRT: {'TP': 496, 'FP': 356, 'TN': 18559, 'FN': 8}
# PRON: {'TP': 554, 'FP': 184, 'TN': 18679, 'FN': 2}
# NUM: {'TP': 320, 'FP': 18, 'TN': 19016, 'FN': 65}
# X: {'TP': 31, 'FP': 2256, 'TN': 17128, 'FN': 4}
#
# Tag with the most false positives is: X with 2256 counts.
# Tag with the most false negative is:  NOUN with 1711 counts.
# sentence:       ['Still', 'more', 'time', 'was', 'consumed', 'while', 'the', 'pilot', ',', 'at', 'the', 'radioed', 'suggestion', 'of', 'Continental', 'president', 'Robert', 'Six', ',', 'tried', 'to', 'persuade', 'the', 'armed', 'pair', 'to', 'swap', 'the', 'Boeing', 'jet', 'for', 'a', 'propeller-driven', 'Douglas', 'Aj', '.']
# hidden s:       ['ADV', 'ADJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'DET', 'VERB', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', 'NOUN', '.', 'VERB', 'PRT', 'VERB', 'DET', 'VERB', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', '.']
# predictions:    ['ADV', 'ADV', 'NOUN', 'VERB', 'X', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'DET', 'X', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', 'NUM', '.', 'VERB', 'PRT', 'VERB', 'DET', 'VERB', 'NOUN', 'PRT', 'X', 'DET', 'X', 'NOUN', 'ADP', 'DET', 'X', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2285, 'FP': 6, 'TN': 17094, 'FN': 70}
# NOUN: {'TP': 3317, 'FP': 76, 'TN': 14349, 'FN': 1713}
# ADJ: {'TP': 1024, 'FP': 215, 'TN': 17668, 'FN': 548}
# VERB: {'TP': 2256, 'FP': 268, 'TN': 16406, 'FN': 525}
# ADP: {'TP': 1772, 'FP': 14, 'TN': 17026, 'FN': 643}
# .: {'TP': 2382, 'FP': 0, 'TN': 17073, 'FN': 0}
# ADV: {'TP': 725, 'FP': 304, 'TN': 18300, 'FN': 126}
# CONJ: {'TP': 583, 'FP': 5, 'TN': 18863, 'FN': 4}
# PRT: {'TP': 498, 'FP': 356, 'TN': 18593, 'FN': 8}
# PRON: {'TP': 554, 'FP': 184, 'TN': 18715, 'FN': 2}
# NUM: {'TP': 320, 'FP': 19, 'TN': 19051, 'FN': 65}
# X: {'TP': 31, 'FP': 2261, 'TN': 17159, 'FN': 4}
#
# Tag with the most false positives is: X with 2261 counts.
# Tag with the most false negative is:  NOUN with 1713 counts.
# sentence:       ['Actually', ',', 'the', 'officers', 'on', 'the', 'ground', 'had', 'no', 'intention', 'of', 'letting', 'the', 'hijackers', 'get', 'away', 'with', 'any', 'kind', 'of', 'an', 'airplane', ';', ';', 'they', 'had', 'orders', 'to', 'that', 'effect', 'straight', 'from', 'President', 'Kennedy', ',', 'who', 'thought', 'at', 'first', ',', 'as', 'did', 'most', 'others', ',', 'that', 'it', 'was', 'four', 'followers', 'of', "Cuba's", 'Fidel', 'Castro', 'who', 'had', 'taken', 'over', 'the', '707', '.']
# hidden s:       ['ADV', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'VERB', 'DET', 'NOUN', 'VERB', 'ADV', 'ADP', 'DET', 'ADJ', 'ADP', 'DET', 'NOUN', '.', '.', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADV', 'ADP', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'ADJ', '.', 'ADV', 'VERB', 'ADJ', 'NOUN', '.', 'ADP', 'PRON', 'VERB', 'NUM', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', 'PRON', 'VERB', 'VERB', 'PRT', 'DET', 'NUM', '.']
# predictions:    ['ADV', '.', 'DET', 'NOUN', 'PRT', 'DET', 'NOUN', 'VERB', 'ADV', 'NOUN', 'ADP', 'VERB', 'DET', 'X', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'X', '.', '.', 'PRON', 'VERB', 'NOUN', 'PRT', 'PRON', 'VERB', 'ADV', 'ADP', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'ADJ', '.', 'ADV', 'VERB', 'ADV', 'NOUN', '.', 'PRON', 'PRON', 'VERB', 'NUM', 'NOUN', 'ADP', 'X', 'NOUN', 'NOUN', 'PRON', 'VERB', 'VERB', 'PRT', 'DET', 'X', '.']
# DET: {'TP': 2291, 'FP': 6, 'TN': 17147, 'FN': 72}
# NOUN: {'TP': 3327, 'FP': 77, 'TN': 14395, 'FN': 1717}
# ADJ: {'TP': 1025, 'FP': 215, 'TN': 17726, 'FN': 550}
# VERB: {'TP': 2265, 'FP': 269, 'TN': 16457, 'FN': 525}
# ADP: {'TP': 1778, 'FP': 14, 'TN': 17078, 'FN': 646}
# .: {'TP': 2389, 'FP': 0, 'TN': 17127, 'FN': 0}
# ADV: {'TP': 729, 'FP': 306, 'TN': 18355, 'FN': 126}
# CONJ: {'TP': 583, 'FP': 5, 'TN': 18924, 'FN': 4}
# PRT: {'TP': 499, 'FP': 358, 'TN': 18651, 'FN': 8}
# PRON: {'TP': 558, 'FP': 186, 'TN': 18770, 'FN': 2}
# NUM: {'TP': 321, 'FP': 19, 'TN': 19110, 'FN': 66}
# X: {'TP': 31, 'FP': 2265, 'TN': 17216, 'FN': 4}
#
# Tag with the most false positives is: X with 2265 counts.
# Tag with the most false negative is:  NOUN with 1717 counts.
# sentence:       ['Mr.', 'Kennedy', 'had', 'been', 'informed', 'early', 'in', 'the', 'day', 'of', 'the', 'attempt', 'to', 'steal', 'the', 'plane', ',', 'kept', 'in', 'touch', 'throughout', 'by', 'telephone', '.']
# hidden s:       ['NOUN', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'NOUN', 'ADV', 'ADP', 'NOUN', '.']
# predictions:    ['NOUN', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'PRT', 'X', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'NOUN', 'ADP', 'ADP', 'NOUN', '.']
# DET: {'TP': 2294, 'FP': 6, 'TN': 17168, 'FN': 72}
# NOUN: {'TP': 3334, 'FP': 77, 'TN': 14412, 'FN': 1717}
# ADJ: {'TP': 1025, 'FP': 215, 'TN': 17750, 'FN': 550}
# VERB: {'TP': 2269, 'FP': 269, 'TN': 16476, 'FN': 526}
# ADP: {'TP': 1782, 'FP': 15, 'TN': 17097, 'FN': 646}
# .: {'TP': 2391, 'FP': 0, 'TN': 17149, 'FN': 0}
# ADV: {'TP': 730, 'FP': 306, 'TN': 18377, 'FN': 127}
# CONJ: {'TP': 583, 'FP': 5, 'TN': 18948, 'FN': 4}
# PRT: {'TP': 500, 'FP': 358, 'TN': 18674, 'FN': 8}
# PRON: {'TP': 558, 'FP': 186, 'TN': 18794, 'FN': 2}
# NUM: {'TP': 321, 'FP': 19, 'TN': 19134, 'FN': 66}
# X: {'TP': 31, 'FP': 2266, 'TN': 17239, 'FN': 4}
#
# Tag with the most false positives is: X with 2266 counts.
# Tag with the most false negative is:  NOUN with 1717 counts.
# sentence:       ['At', 'one', 'time', ',', 'while', 'still', 'under', 'the', 'impression', 'that', 'he', 'was', 'dealing', 'with', 'a', 'Cuban', 'plot', ',', 'the', 'President', 'talked', 'about', 'invoking', 'a', 'total', 'embargo', 'on', 'trade', 'with', 'Cuba', '.']
# hidden s:       ['ADP', 'NUM', 'NOUN', '.', 'ADP', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'DET', 'NOUN', 'VERB', 'ADP', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['ADP', 'NUM', 'NOUN', '.', 'ADP', 'ADV', 'ADP', 'DET', 'NOUN', 'PRON', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'VERB', 'ADV', 'VERB', 'DET', 'VERB', 'X', 'PRT', 'NOUN', 'ADP', 'NOUN', '.']
# DET: {'TP': 2298, 'FP': 6, 'TN': 17195, 'FN': 72}
# NOUN: {'TP': 3340, 'FP': 78, 'TN': 14434, 'FN': 1719}
# ADJ: {'TP': 1025, 'FP': 215, 'TN': 17780, 'FN': 551}
# VERB: {'TP': 2273, 'FP': 270, 'TN': 16502, 'FN': 526}
# ADP: {'TP': 1787, 'FP': 15, 'TN': 17120, 'FN': 649}
# .: {'TP': 2394, 'FP': 0, 'TN': 17177, 'FN': 0}
# ADV: {'TP': 731, 'FP': 307, 'TN': 18406, 'FN': 127}
# CONJ: {'TP': 583, 'FP': 5, 'TN': 18979, 'FN': 4}
# PRT: {'TP': 500, 'FP': 359, 'TN': 18704, 'FN': 8}
# PRON: {'TP': 559, 'FP': 187, 'TN': 18823, 'FN': 2}
# NUM: {'TP': 322, 'FP': 19, 'TN': 19164, 'FN': 66}
# X: {'TP': 31, 'FP': 2267, 'TN': 17269, 'FN': 4}
#
# Tag with the most false positives is: X with 2267 counts.
# Tag with the most false negative is:  NOUN with 1719 counts.
# sentence:       ['As', 'the', 'morning', 'wore', 'on', 'and', 'a', 'blazing', 'West', 'Texas', 'sun', 'wiped', 'the', 'shadows', 'off', 'the', 'Franklin', 'Mountains', ',', 'police', 'got', 'close', 'enough', 'to', 'the', 'plane', 'to', 'pry', 'into', 'the', 'baggage', 'compartment', '.']
# hidden s:       ['ADP', 'DET', 'NOUN', 'VERB', 'PRT', 'CONJ', 'DET', 'VERB', 'ADJ', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'NOUN', 'VERB', 'ADV', 'ADV', 'ADP', 'DET', 'NOUN', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', '.']
# predictions:    ['ADP', 'DET', 'NOUN', 'VERB', 'PRT', 'CONJ', 'DET', 'VERB', 'ADJ', 'NOUN', 'NOUN', 'VERB', 'DET', 'X', 'PRT', 'DET', 'NOUN', 'X', '.', 'NOUN', 'VERB', 'ADV', 'ADV', 'PRT', 'DET', 'NOUN', 'PRT', 'X', 'ADP', 'DET', 'X', 'NOUN', '.']
# DET: {'TP': 2304, 'FP': 6, 'TN': 17222, 'FN': 72}
# NOUN: {'TP': 3347, 'FP': 78, 'TN': 14457, 'FN': 1722}
# ADJ: {'TP': 1026, 'FP': 215, 'TN': 17812, 'FN': 551}
# VERB: {'TP': 2277, 'FP': 270, 'TN': 16530, 'FN': 527}
# ADP: {'TP': 1789, 'FP': 15, 'TN': 17149, 'FN': 651}
# .: {'TP': 2396, 'FP': 0, 'TN': 17208, 'FN': 0}
# ADV: {'TP': 733, 'FP': 307, 'TN': 18437, 'FN': 127}
# CONJ: {'TP': 584, 'FP': 5, 'TN': 19011, 'FN': 4}
# PRT: {'TP': 502, 'FP': 361, 'TN': 18733, 'FN': 8}
# PRON: {'TP': 559, 'FP': 187, 'TN': 18856, 'FN': 2}
# NUM: {'TP': 322, 'FP': 19, 'TN': 19197, 'FN': 66}
# X: {'TP': 31, 'FP': 2271, 'TN': 17298, 'FN': 4}
#
# Tag with the most false positives is: X with 2271 counts.
# Tag with the most false negative is:  NOUN with 1722 counts.
# sentence:       ['From', 'the', 'luggage', ',', 'they', 'learned', 'that', 'the', 'two', 'air', 'pirates', ',', 'far', 'from', 'being', 'Cubans', ',', 'were', 'native', 'Americans', ',', 'subsequently', 'identified', 'as', 'Leon', 'Bearden', ',', '50-year-old', 'ex-convict', 'from', 'Coolidge', ',', 'Ariz.', ',', 'and', 'his', 'son', ',', 'Cody', ',', '16', ',', 'a', 'high-school', 'junior', '.']
# hidden s:       ['ADP', 'DET', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'DET', 'NUM', 'NOUN', 'NOUN', '.', 'ADV', 'ADP', 'VERB', 'NOUN', '.', 'VERB', 'ADJ', 'NOUN', '.', 'ADV', 'VERB', 'ADP', 'NOUN', 'NOUN', '.', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', '.', 'NOUN', '.', 'NUM', '.', 'DET', 'NOUN', 'NOUN', '.']
# predictions:    ['ADP', 'DET', 'X', '.', 'PRON', 'VERB', 'PRON', 'DET', 'NUM', 'NOUN', 'X', '.', 'ADV', 'ADP', 'VERB', 'NOUN', '.', 'VERB', 'NOUN', 'NOUN', '.', 'X', 'VERB', 'ADV', 'NOUN', 'X', '.', 'X', 'X', 'ADP', 'X', '.', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', '.', 'X', '.', 'NUM', '.', 'DET', 'X', 'ADJ', '.']
# DET: {'TP': 2308, 'FP': 6, 'TN': 17264, 'FN': 72}
# NOUN: {'TP': 3353, 'FP': 79, 'TN': 14488, 'FN': 1730}
# ADJ: {'TP': 1026, 'FP': 216, 'TN': 17855, 'FN': 553}
# VERB: {'TP': 2281, 'FP': 270, 'TN': 16572, 'FN': 527}
# ADP: {'TP': 1792, 'FP': 15, 'TN': 17190, 'FN': 653}
# .: {'TP': 2407, 'FP': 0, 'TN': 17243, 'FN': 0}
# ADV: {'TP': 734, 'FP': 308, 'TN': 18480, 'FN': 128}
# CONJ: {'TP': 585, 'FP': 5, 'TN': 19056, 'FN': 4}
# PRT: {'TP': 502, 'FP': 361, 'TN': 18779, 'FN': 8}
# PRON: {'TP': 560, 'FP': 188, 'TN': 18900, 'FN': 2}
# NUM: {'TP': 324, 'FP': 19, 'TN': 19241, 'FN': 66}
# X: {'TP': 31, 'FP': 2280, 'TN': 17335, 'FN': 4}
#
# Tag with the most false positives is: X with 2280 counts.
# Tag with the most false negative is:  NOUN with 1730 counts.
# sentence:       ['Tension', 'The', 'heat', 'and', 'strain', 'began', 'to', 'tell', 'on', 'the', 'Beardens', '.']
# hidden s:       ['NOUN', 'DET', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['ADJ', 'DET', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'PRT', 'VERB', 'PRT', 'DET', 'X', '.']
# DET: {'TP': 2310, 'FP': 6, 'TN': 17274, 'FN': 72}
# NOUN: {'TP': 3355, 'FP': 79, 'TN': 14496, 'FN': 1732}
# ADJ: {'TP': 1026, 'FP': 217, 'TN': 17866, 'FN': 553}
# VERB: {'TP': 2283, 'FP': 270, 'TN': 16582, 'FN': 527}
# ADP: {'TP': 1792, 'FP': 15, 'TN': 17201, 'FN': 654}
# .: {'TP': 2408, 'FP': 0, 'TN': 17254, 'FN': 0}
# ADV: {'TP': 734, 'FP': 308, 'TN': 18492, 'FN': 128}
# CONJ: {'TP': 586, 'FP': 5, 'TN': 19067, 'FN': 4}
# PRT: {'TP': 503, 'FP': 362, 'TN': 18789, 'FN': 8}
# PRON: {'TP': 560, 'FP': 188, 'TN': 18912, 'FN': 2}
# NUM: {'TP': 324, 'FP': 19, 'TN': 19253, 'FN': 66}
# X: {'TP': 31, 'FP': 2281, 'TN': 17346, 'FN': 4}
#
# Tag with the most false positives is: X with 2281 counts.
# Tag with the most false negative is:  NOUN with 1732 counts.
# sentence:       ['The', 'father', ',', 'by', 'accident', 'or', 'perhaps', 'to', 'show', ',', 'as', 'he', 'said', ',', '``', 'we', 'mean', 'business', "''", ',', 'took', 'the', 'and', 'fired', 'a', 'slug', 'between', 'the', 'legs', 'of', 'Second', 'Officer', 'Norman', 'Simmons', '.']
# hidden s:       ['DET', 'NOUN', '.', 'ADP', 'NOUN', 'CONJ', 'ADV', 'PRT', 'VERB', '.', 'ADP', 'PRON', 'VERB', '.', '.', 'PRON', 'VERB', 'NOUN', '.', '.', 'VERB', 'DET', 'CONJ', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', '.', 'ADP', 'NOUN', 'CONJ', 'ADV', 'PRT', 'VERB', '.', 'ADV', 'PRON', 'VERB', '.', '.', 'PRON', 'VERB', 'NOUN', '.', '.', 'VERB', 'DET', 'CONJ', 'VERB', 'DET', 'X', 'ADP', 'DET', 'NOUN', 'ADP', 'ADV', 'X', 'NOUN', 'X', '.']
# DET: {'TP': 2314, 'FP': 6, 'TN': 17305, 'FN': 72}
# NOUN: {'TP': 3360, 'FP': 79, 'TN': 14523, 'FN': 1735}
# ...
# DET: {'TP': 2882, 'FP': 7, 'TN': 21881, 'FN': 82}
# NOUN: {'TP': 4300, 'FP': 88, 'TN': 18243, 'FN': 2221}
# ADJ: {'TP': 1313, 'FP': 263, 'TN': 22607, 'FN': 669}
# VERB: {'TP': 2925, 'FP': 351, 'TN': 20935, 'FN': 641}
# ADP: {'TP': 2319, 'FP': 24, 'TN': 21685, 'FN': 824}
# .: {'TP': 3060, 'FP': 0, 'TN': 21792, 'FN': 0}
# ADV: {'TP': 917, 'FP': 392, 'TN': 23391, 'FN': 152}
# CONJ: {'TP': 719, 'FP': 6, 'TN': 24123, 'FN': 4}
# PRT: {'TP': 641, 'FP': 477, 'TN': 23721, 'FN': 13}
# PRON: {'TP': 644, 'FP': 219, 'TN': 23986, 'FN': 3}
# NUM: {'TP': 399, 'FP': 26, 'TN': 24344, 'FN': 83}
# X: {'TP': 36, 'FP': 2844, 'TN': 21967, 'FN': 5}
#
# Tag with the most false positives is: X with 2844 counts.
# Tag with the most false negative is:  NOUN with 2221 counts.
# sentence:       ['We', 'must', 'not', 'permit', 'our', 'society', 'to', 'become', 'a', 'slave', 'to', 'the', 'scientific', 'age', ',', 'as', 'might', 'well', 'happen', 'without', 'the', 'cultural', 'and', 'spiritual', 'restraint', 'that', 'comes', 'from', 'the', 'development', 'of', 'the', 'human', 'mind', 'through', 'wisdom', 'absorbed', 'from', 'the', 'written', 'word', '.']
# hidden s:       ['PRON', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADP', 'VERB', 'ADV', 'VERB', 'ADP', 'DET', 'ADJ', 'CONJ', 'ADJ', 'NOUN', 'DET', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', '.']
# predictions:    ['PRON', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'X', 'PRT', 'DET', 'ADJ', 'NOUN', '.', 'ADV', 'VERB', 'ADV', 'VERB', 'ADP', 'DET', 'ADJ', 'CONJ', 'X', 'X', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'PRT', 'NOUN', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', '.']
# DET: {'TP': 2889, 'FP': 7, 'TN': 21915, 'FN': 83}
# NOUN: {'TP': 4307, 'FP': 88, 'TN': 18276, 'FN': 2223}
# ADJ: {'TP': 1315, 'FP': 263, 'TN': 22646, 'FN': 670}
# VERB: {'TP': 2933, 'FP': 351, 'TN': 20969, 'FN': 641}
# ADP: {'TP': 2323, 'FP': 24, 'TN': 21720, 'FN': 827}
# .: {'TP': 3062, 'FP': 0, 'TN': 21832, 'FN': 0}
# ADV: {'TP': 919, 'FP': 393, 'TN': 23430, 'FN': 152}
# CONJ: {'TP': 720, 'FP': 6, 'TN': 24164, 'FN': 4}
# PRT: {'TP': 642, 'FP': 479, 'TN': 23760, 'FN': 13}
# PRON: {'TP': 645, 'FP': 220, 'TN': 24026, 'FN': 3}
# NUM: {'TP': 399, 'FP': 26, 'TN': 24386, 'FN': 83}
# X: {'TP': 36, 'FP': 2847, 'TN': 22006, 'FN': 5}
#
# Tag with the most false positives is: X with 2847 counts.
# Tag with the most false negative is:  NOUN with 2223 counts.
# sentence:       ['A', 'fundamental', 'source', 'of', 'knowledge', 'in', 'the', 'world', 'today', 'is', 'the', 'book', 'found', 'in', 'our', 'libraries', '.']
# hidden s:       ['DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'X', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'VERB', 'ADP', 'DET', 'X', '.']
# DET: {'TP': 2893, 'FP': 7, 'TN': 21928, 'FN': 83}
# NOUN: {'TP': 4312, 'FP': 88, 'TN': 18287, 'FN': 2224}
# ADJ: {'TP': 1315, 'FP': 263, 'TN': 22662, 'FN': 671}
# VERB: {'TP': 2935, 'FP': 351, 'TN': 20984, 'FN': 641}
# ADP: {'TP': 2326, 'FP': 24, 'TN': 21734, 'FN': 827}
# .: {'TP': 3063, 'FP': 0, 'TN': 21848, 'FN': 0}
# ADV: {'TP': 919, 'FP': 393, 'TN': 23447, 'FN': 152}
# CONJ: {'TP': 720, 'FP': 6, 'TN': 24181, 'FN': 4}
# PRT: {'TP': 642, 'FP': 479, 'TN': 23777, 'FN': 13}
# PRON: {'TP': 645, 'FP': 220, 'TN': 24043, 'FN': 3}
# NUM: {'TP': 399, 'FP': 26, 'TN': 24403, 'FN': 83}
# X: {'TP': 36, 'FP': 2849, 'TN': 22021, 'FN': 5}
#
# Tag with the most false positives is: X with 2849 counts.
# Tag with the most false negative is:  NOUN with 2224 counts.
# sentence:       ['Although', 'progress', 'has', 'been', 'made', 'in', "America's", 'system', 'of', 'libraries', 'it', 'still', 'falls', 'short', 'of', 'what', 'is', 'required', 'if', 'we', 'are', 'to', 'maintain', 'the', 'standards', 'that', 'are', 'needed', 'for', 'an', 'informed', 'America', '.']
# hidden s:       ['ADP', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'PRON', 'ADV', 'VERB', 'ADV', 'ADP', 'DET', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', '.']
# predictions:    ['ADP', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'NOUN', 'NOUN', 'ADP', 'X', 'PRON', 'ADV', 'X', 'ADV', 'ADP', 'DET', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', '.']
# DET: {'TP': 2896, 'FP': 7, 'TN': 21958, 'FN': 83}
# NOUN: {'TP': 4317, 'FP': 88, 'TN': 18314, 'FN': 2225}
# ADJ: {'TP': 1315, 'FP': 263, 'TN': 22695, 'FN': 671}
# VERB: {'TP': 2945, 'FP': 351, 'TN': 21006, 'FN': 642}
# ADP: {'TP': 2332, 'FP': 24, 'TN': 21761, 'FN': 827}
# .: {'TP': 3064, 'FP': 0, 'TN': 21880, 'FN': 0}
# ADV: {'TP': 921, 'FP': 393, 'TN': 23478, 'FN': 152}
# CONJ: {'TP': 720, 'FP': 6, 'TN': 24214, 'FN': 4}
# PRT: {'TP': 643, 'FP': 479, 'TN': 23809, 'FN': 13}
# PRON: {'TP': 648, 'FP': 220, 'TN': 24073, 'FN': 3}
# NUM: {'TP': 399, 'FP': 26, 'TN': 24436, 'FN': 83}
# X: {'TP': 36, 'FP': 2851, 'TN': 22052, 'FN': 5}
#
# Tag with the most false positives is: X with 2851 counts.
# Tag with the most false negative is:  NOUN with 2225 counts.
# sentence:       ['The', 'problem', 'grows', 'in', 'intensity', 'each', 'year', 'as', "man's", 'knowledge', ',', 'and', 'his', 'capacity', 'to', 'translate', 'such', 'knowledge', 'to', 'the', 'written', 'word', ',', 'continue', 'to', 'expand', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'ADP', 'NOUN', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', 'PRT', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'VERB', 'NOUN', '.', 'VERB', 'PRT', 'VERB', '.']
# predictions:    ['DET', 'NOUN', 'X', 'ADP', 'NOUN', 'DET', 'NOUN', 'ADV', 'NOUN', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', 'PRT', 'X', 'PRT', 'NOUN', 'PRT', 'DET', 'VERB', 'NOUN', '.', 'VERB', 'PRT', 'VERB', '.']
# DET: {'TP': 2900, 'FP': 7, 'TN': 21981, 'FN': 83}
# NOUN: {'TP': 4325, 'FP': 88, 'TN': 18333, 'FN': 2225}
# ADJ: {'TP': 1315, 'FP': 263, 'TN': 22721, 'FN': 672}
# VERB: {'TP': 2948, 'FP': 351, 'TN': 21028, 'FN': 644}
# ADP: {'TP': 2333, 'FP': 24, 'TN': 21785, 'FN': 829}
# .: {'TP': 3067, 'FP': 0, 'TN': 21904, 'FN': 0}
# ADV: {'TP': 921, 'FP': 394, 'TN': 23504, 'FN': 152}
# CONJ: {'TP': 721, 'FP': 6, 'TN': 24240, 'FN': 4}
# PRT: {'TP': 645, 'FP': 481, 'TN': 23832, 'FN': 13}
# PRON: {'TP': 648, 'FP': 220, 'TN': 24100, 'FN': 3}
# NUM: {'TP': 399, 'FP': 26, 'TN': 24463, 'FN': 83}
# X: {'TP': 36, 'FP': 2853, 'TN': 22077, 'FN': 5}
#
# Tag with the most false positives is: X with 2853 counts.
# Tag with the most false negative is:  NOUN with 2225 counts.
# sentence:       ['The', 'inadequacy', 'of', 'our', 'library', 'system', 'will', 'become', 'critical', 'unless', 'we', 'act', 'vigorously', 'to', 'correct', 'this', 'condition', '.']
# hidden s:       ['DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADJ', 'ADP', 'PRON', 'VERB', 'ADV', 'PRT', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'X', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADJ', 'ADP', 'PRON', 'NOUN', 'X', 'PRT', 'ADJ', 'DET', 'NOUN', '.']
# DET: {'TP': 2903, 'FP': 7, 'TN': 21996, 'FN': 83}
# NOUN: {'TP': 4328, 'FP': 89, 'TN': 18346, 'FN': 2226}
# ADJ: {'TP': 1316, 'FP': 264, 'TN': 22737, 'FN': 672}
# VERB: {'TP': 2950, 'FP': 351, 'TN': 21042, 'FN': 646}
# ADP: {'TP': 2335, 'FP': 24, 'TN': 21801, 'FN': 829}
# .: {'TP': 3068, 'FP': 0, 'TN': 21921, 'FN': 0}
# ADV: {'TP': 921, 'FP': 394, 'TN': 23521, 'FN': 153}
# CONJ: {'TP': 721, 'FP': 6, 'TN': 24258, 'FN': 4}
# PRT: {'TP': 646, 'FP': 481, 'TN': 23849, 'FN': 13}
# PRON: {'TP': 649, 'FP': 220, 'TN': 24117, 'FN': 3}
# NUM: {'TP': 399, 'FP': 26, 'TN': 24481, 'FN': 83}
# X: {'TP': 36, 'FP': 2855, 'TN': 22093, 'FN': 5}
#
# Tag with the most false positives is: X with 2855 counts.
# Tag with the most false negative is:  NOUN with 2226 counts.
# sentence:       ['There', 'are', ',', 'for', 'example', ',', 'approximately', '25,000,000', 'people', 'in', 'this', 'country', 'with', 'no', 'public', 'library', 'service', 'and', 'about', '50,000,000', 'with', 'inadequate', 'service', '.']
# hidden s:       ['PRT', 'VERB', '.', 'ADP', 'NOUN', '.', 'ADV', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'CONJ', 'ADV', 'NUM', 'ADP', 'ADJ', 'NOUN', '.']
# predictions:    ['PRT', 'VERB', '.', 'ADP', 'NOUN', '.', 'ADV', 'X', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'ADV', 'ADJ', 'NOUN', 'NOUN', 'CONJ', 'ADV', 'X', 'ADP', 'ADJ', 'NOUN', '.']
# DET: {'TP': 2904, 'FP': 7, 'TN': 22018, 'FN': 84}
# NOUN: {'TP': 4334, 'FP': 89, 'TN': 18364, 'FN': 2226}
# ADJ: {'TP': 1318, 'FP': 264, 'TN': 22759, 'FN': 672}
# VERB: {'TP': 2951, 'FP': 351, 'TN': 21065, 'FN': 646}
# ADP: {'TP': 2339, 'FP': 24, 'TN': 21821, 'FN': 829}
# .: {'TP': 3071, 'FP': 0, 'TN': 21942, 'FN': 0}
# ADV: {'TP': 923, 'FP': 395, 'TN': 23542, 'FN': 153}
# CONJ: {'TP': 722, 'FP': 6, 'TN': 24281, 'FN': 4}
# PRT: {'TP': 647, 'FP': 481, 'TN': 23872, 'FN': 13}
# PRON: {'TP': 649, 'FP': 220, 'TN': 24141, 'FN': 3}
# NUM: {'TP': 399, 'FP': 26, 'TN': 24503, 'FN': 85}
# X: {'TP': 36, 'FP': 2857, 'TN': 22115, 'FN': 5}
#
# Tag with the most false positives is: X with 2857 counts.
# Tag with the most false negative is:  NOUN with 2226 counts.
# sentence:       ['In', 'college', 'libraries', ',', '57', 'per', 'cent', 'of', 'the', 'total', 'number', 'of', 'books', 'are', 'owned', 'by', '124', 'of', '1,509', 'institutions', 'surveyed', 'last', 'year', 'by', 'the', 'U.S.', 'Office', 'of', 'Education', '.']
# hidden s:       ['ADP', 'NOUN', 'NOUN', '.', 'NUM', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'ADP', 'NUM', 'ADP', 'NUM', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['ADP', 'NOUN', 'X', '.', 'X', 'ADP', 'NOUN', 'ADP', 'DET', 'VERB', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'ADP', 'X', 'ADP', 'X', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.']
# DET: {'TP': 2906, 'FP': 7, 'TN': 22046, 'FN': 84}
# NOUN: {'TP': 4343, 'FP': 89, 'TN': 18383, 'FN': 2228}
# ADJ: {'TP': 1319, 'FP': 264, 'TN': 22788, 'FN': 672}
# VERB: {'TP': 2954, 'FP': 352, 'TN': 21091, 'FN': 646}
# ADP: {'TP': 2347, 'FP': 24, 'TN': 21843, 'FN': 829}
# .: {'TP': 3073, 'FP': 0, 'TN': 21970, 'FN': 0}
# ADV: {'TP': 923, 'FP': 395, 'TN': 23572, 'FN': 153}
# CONJ: {'TP': 722, 'FP': 6, 'TN': 24311, 'FN': 4}
# PRT: {'TP': 647, 'FP': 481, 'TN': 23902, 'FN': 13}
# PRON: {'TP': 649, 'FP': 220, 'TN': 24171, 'FN': 3}
# NUM: {'TP': 399, 'FP': 26, 'TN': 24530, 'FN': 88}
# X: {'TP': 36, 'FP': 2861, 'TN': 22141, 'FN': 5}
#
# Tag with the most false positives is: X with 2861 counts.
# Tag with the most false negative is:  NOUN with 2228 counts.
# sentence:       ['And', 'over', '66', 'per', 'cent', 'of', 'the', 'elementary', 'schools', 'with', '150', 'or', 'more', 'pupils', 'do', 'not', 'have', 'any', 'library', 'at', 'all', '.']
# hidden s:       ['CONJ', 'PRT', 'NUM', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NUM', 'CONJ', 'ADJ', 'NOUN', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'ADP', 'PRT', '.']
# predictions:    ['CONJ', 'PRT', 'X', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NUM', 'CONJ', 'ADV', 'X', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'ADP', 'PRT', '.']
# DET: {'TP': 2908, 'FP': 7, 'TN': 22066, 'FN': 84}
# NOUN: {'TP': 4346, 'FP': 89, 'TN': 18401, 'FN': 2229}
# ADJ: {'TP': 1320, 'FP': 264, 'TN': 22808, 'FN': 673}
# VERB: {'TP': 2956, 'FP': 352, 'TN': 21111, 'FN': 646}
# ADP: {'TP': 2351, 'FP': 24, 'TN': 21861, 'FN': 829}
# .: {'TP': 3074, 'FP': 0, 'TN': 21991, 'FN': 0}
# ADV: {'TP': 924, 'FP': 396, 'TN': 23592, 'FN': 153}
# CONJ: {'TP': 724, 'FP': 6, 'TN': 24331, 'FN': 4}
# PRT: {'TP': 649, 'FP': 481, 'TN': 23922, 'FN': 13}
# PRON: {'TP': 649, 'FP': 220, 'TN': 24193, 'FN': 3}
# NUM: {'TP': 400, 'FP': 26, 'TN': 24550, 'FN': 89}
# X: {'TP': 36, 'FP': 2863, 'TN': 22161, 'FN': 5}
#
# Tag with the most false positives is: X with 2863 counts.
# Tag with the most false negative is:  NOUN with 2229 counts.
# sentence:       ['In', 'every', 'aspect', 'of', 'service', '--', 'to', 'the', 'public', ',', 'to', 'children', 'in', 'schools', ',', 'to', 'colleges', 'and', 'universities', '--', 'the', 'library', 'of', 'today', 'is', 'failing', 'to', 'render', 'vitally', 'needed', 'services', '.']
# hidden s:       ['ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'NOUN', 'CONJ', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'PRT', 'VERB', 'ADV', 'VERB', 'NOUN', '.']
# predictions:    ['ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'PRT', 'DET', 'ADJ', '.', 'PRT', 'NOUN', 'ADP', 'NOUN', '.', 'PRT', 'NOUN', 'CONJ', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'PRT', 'X', 'X', 'VERB', 'NOUN', '.']
# DET: {'TP': 2911, 'FP': 7, 'TN': 22095, 'FN': 84}
# NOUN: {'TP': 4355, 'FP': 89, 'TN': 18423, 'FN': 2230}
# ADJ: {'TP': 1320, 'FP': 265, 'TN': 22839, 'FN': 673}
# VERB: {'TP': 2959, 'FP': 352, 'TN': 21139, 'FN': 647}
# ADP: {'TP': 2355, 'FP': 24, 'TN': 21886, 'FN': 832}
# .: {'TP': 3079, 'FP': 0, 'TN': 22018, 'FN': 0}
# ADV: {'TP': 924, 'FP': 396, 'TN': 23623, 'FN': 154}
# CONJ: {'TP': 725, 'FP': 6, 'TN': 24362, 'FN': 4}
# PRT: {'TP': 650, 'FP': 484, 'TN': 23950, 'FN': 13}
# PRON: {'TP': 649, 'FP': 220, 'TN': 24225, 'FN': 3}
# NUM: {'TP': 400, 'FP': 26, 'TN': 24582, 'FN': 89}
# X: {'TP': 36, 'FP': 2865, 'TN': 22191, 'FN': 5}
#
# Tag with the most false positives is: X with 2865 counts.
# Tag with the most false negative is:  NOUN with 2230 counts.
# sentence:       ['Only', 'public', 'understanding', 'and', 'support', 'can', 'provide', 'that', 'service', '.']
# hidden s:       ['ADJ', 'ADJ', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['ADV', 'ADJ', 'VERB', 'CONJ', 'VERB', 'VERB', 'VERB', 'PRON', 'NOUN', '.']
# DET: {'TP': 2911, 'FP': 7, 'TN': 22104, 'FN': 85}
# NOUN: {'TP': 4356, 'FP': 89, 'TN': 18430, 'FN': 2232}
# ADJ: {'TP': 1321, 'FP': 265, 'TN': 22847, 'FN': 674}
# VERB: {'TP': 2961, 'FP': 354, 'TN': 21145, 'FN': 647}
# ADP: {'TP': 2355, 'FP': 24, 'TN': 21896, 'FN': 832}
# .: {'TP': 3080, 'FP': 0, 'TN': 22027, 'FN': 0}
# ADV: {'TP': 924, 'FP': 397, 'TN': 23632, 'FN': 154}
# CONJ: {'TP': 726, 'FP': 6, 'TN': 24371, 'FN': 4}
# PRT: {'TP': 650, 'FP': 484, 'TN': 23960, 'FN': 13}
# PRON: {'TP': 649, 'FP': 221, 'TN': 24234, 'FN': 3}
# NUM: {'TP': 400, 'FP': 26, 'TN': 24592, 'FN': 89}
# X: {'TP': 36, 'FP': 2865, 'TN': 22201, 'FN': 5}
#
# Tag with the most false positives is: X with 2865 counts.
# Tag with the most false negative is:  NOUN with 2232 counts.
# sentence:       ['This', 'is', 'one', 'of', 'the', 'main', 'reasons', 'for', 'National', 'Library', 'Week', ',', 'April', '16-22', ',', 'and', 'for', 'its', 'theme', ':', '``', 'For', 'a', 'richer', ',', 'fuller', 'life', ',', 'read', "''", '!', '!']
# hidden s:       ['DET', 'VERB', 'NUM', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', '.', 'NOUN', 'NUM', '.', 'CONJ', 'ADP', 'DET', 'NOUN', '.', '.', 'ADP', 'DET', 'ADJ', '.', 'ADJ', 'NOUN', '.', 'VERB', '.', '.', '.']
# predictions:    ['DET', 'VERB', 'NUM', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', '.', 'NOUN', 'X', '.', 'CONJ', 'ADP', 'DET', 'NOUN', '.', '.', 'ADP', 'DET', 'X', '.', 'X', 'NOUN', '.', 'VERB', '.', '.', '.']
# DET: {'TP': 2915, 'FP': 7, 'TN': 22132, 'FN': 85}
# NOUN: {'TP': 4362, 'FP': 89, 'TN': 18456, 'FN': 2232}
# ADJ: {'TP': 1323, 'FP': 265, 'TN': 22875, 'FN': 676}
# VERB: {'TP': 2963, 'FP': 354, 'TN': 21175, 'FN': 647}
# ADP: {'TP': 2359, 'FP': 24, 'TN': 21924, 'FN': 832}
# .: {'TP': 3089, 'FP': 0, 'TN': 22050, 'FN': 0}
# ADV: {'TP': 924, 'FP': 397, 'TN': 23664, 'FN': 154}
# CONJ: {'TP': 727, 'FP': 6, 'TN': 24402, 'FN': 4}
# PRT: {'TP': 650, 'FP': 484, 'TN': 23992, 'FN': 13}
# PRON: {'TP': 649, 'FP': 221, 'TN': 24266, 'FN': 3}
# NUM: {'TP': 401, 'FP': 26, 'TN': 24622, 'FN': 90}
# X: {'TP': 36, 'FP': 2868, 'TN': 22230, 'FN': 5}
#
# Tag with the most false positives is: X with 2868 counts.
# Tag with the most false negative is:  NOUN with 2232 counts.
#
# model got 20398 samples correct out of 25139
# accuracy: 0.8114085683599188
